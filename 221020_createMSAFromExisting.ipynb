# %%
import os
import pickle
import pandas as pd
from createMSAFromExisting import *

# %% [markdown]
# # Full-length + fragment

# %%
def createIndividualMSAsFullLengthFragment(a3m_path,name,protein_range,fragment_start_range,fragment_length):
    '''Loads a monomer MSA and creates new MSAs that contain 1) a large section of the monomer and 2) a short fragment of the monomer
    
    Args
    ----
    a3m_path : str
        path to an a3m formatted msa file describing the monomeric protein (obtained from colab_mmseqs)
    name : str
        name of the monomeric protein
    protein_range : list
        an inclusive range defining which positions of the MSA to take from the monomeric protein (sometimes the ends need to be chopped off)
    fragment_start_range : list
        an inclusive range defining the range of starting residues for fragments of length `fragment_length`
    fragment_length : int
        the number of residues to take when defining a fragment
    '''
    dir_name = f"{name}_tile{str(fragment_length)}aa"
    try:
        os.makedirs(dir_name, exist_ok=False)
    except FileExistsError:
        print('Directory already exists, possibly overwriting existing files')
            
    for fragment_start in range(fragment_start_range[0],fragment_start_range[1]-fragment_length+1):
        fragment_range = (fragment_start,fragment_start+fragment_length-1) # range is inclusive
        a3m_out_path = f"{dir_name}/{name}_{protein_range[0]}-{protein_range[1]}_{name}_{fragment_range[0]}-{fragment_range[1]}.a3m"
        createMSA(a3m_path, protein_range, fragment_range, -1, a3m_out_path)

# %% [markdown]
# ## Get the fragment ranges for which we have inhibitory data

# %%
path = '/home/gridsan/sswanson/local_code_mirror/ColabFoldCustomMSA/colab_info/Savinov_2022_inhib_peptide_mapping.csv'
inhib_df = pd.read_csv(path)
inhib_df_lptg = inhib_df[(inhib_df['gene']=='lptG-coding-EcoliBL21DE3')]
display(inhib_df_lptg)
inhib_df = inhib_df[(inhib_df['fragment length (aa)']==30)]
inhib_df
# Out:
#                           gene                           fragment ID  \
# 8004  lptG-coding-EcoliBL21DE3       lptG-coding-EcoliBL21DE3_1_42_+
# 8005  lptG-coding-EcoliBL21DE3       lptG-coding-EcoliBL21DE3_4_45_+
# 8006  lptG-coding-EcoliBL21DE3       lptG-coding-EcoliBL21DE3_7_48_+
# 8007  lptG-coding-EcoliBL21DE3      lptG-coding-EcoliBL21DE3_10_51_+
# 8008  lptG-coding-EcoliBL21DE3      lptG-coding-EcoliBL21DE3_13_54_+
# ...                        ...                                   ...
# 8346  lptG-coding-EcoliBL21DE3  lptG-coding-EcoliBL21DE3_1027_1068_+
# 8347  lptG-coding-EcoliBL21DE3  lptG-coding-EcoliBL21DE3_1030_1071_+
# 8348  lptG-coding-EcoliBL21DE3  lptG-coding-EcoliBL21DE3_1033_1074_+
# 8349  lptG-coding-EcoliBL21DE3  lptG-coding-EcoliBL21DE3_1036_1077_+
# 8350  lptG-coding-EcoliBL21DE3  lptG-coding-EcoliBL21DE3_1039_1080_+
#
#       fragment start (aa)  fragment end (aa)  fragment center (aa)  \
# 8004                    1                 14                   7.5
# 8005                    2                 15                   8.5
# 8006                    3                 16                   9.5
# 8007                    4                 17                  10.5
# 8008                    5                 18                  11.5
# ...                   ...                ...                   ...
# 8346                  343                356                 349.5
# 8347                  344                357                 350.5
# 8348                  345                358                 351.5
# 8349                  346                359                 352.5
# 8350                  347                360                 353.5
#
#       fragment length (aa)  E = inhibitory effect (enrichment)    sem(E)  \
# 8004                    14                            0.204406  0.090457
# 8005                    14                            0.165312  0.051304
# 8006                    14                            0.080205  0.013877
# 8007                    14                            0.886631  0.007495
# 8008                    14                            0.563839  0.006706
# ...                    ...                                 ...       ...
# 8346                    14                            0.431270  0.067149
# 8347                    14                            0.302660  0.112773
# 8348                    14                           -0.125619  0.101623
# 8349                    14                           -0.791674  0.025399
# 8350                    14                           -0.633297  0.069276
#
#      hydrophobicity_KyteDoolittle_classifier  \
# 8004                             hydrophilic
# 8005                             hydrophilic
# 8006                             hydrophobic
# 8007                             hydrophobic
# 8008                             hydrophobic
# ...                                      ...
# 8346                             hydrophobic
# 8347                             hydrophobic
# 8348                             hydrophobic
# 8349                             hydrophobic
# 8350                             hydrophobic
#
#      instabIndex_Guruprasad_classifier charge_Lehninger_classifier  \
# 8004                            stable                     neutral
# 8005                            stable                     neutral
# 8006                            stable                     neutral
# 8007                            stable                     neutral
# 8008                            stable                     neutral
# ...                                ...                         ...
# 8346                          unstable                     neutral
# 8347                          unstable                     neutral
# 8348                            stable                     neutral
# 8349                            stable                    positive
# 8350                            stable                    positive
#
#       frag_contains_alphaHelix  frag_contains_betaStrand  frag_contains_Turn  \
# 8004                       1.0                       0.0                 0.0
# 8005                       1.0                       0.0                 0.0
# 8006                       1.0                       0.0                 0.0
# 8007                       1.0                       0.0                 0.0
# 8008                       1.0                       0.0                 0.0
# ...                        ...                       ...                 ...
# 8346                       1.0                       0.0                 0.0
# 8347                       1.0                       0.0                 0.0
# 8348                       1.0                       0.0                 0.0
# 8349                       1.0                       0.0                 0.0
# 8350                       1.0                       0.0                 0.0
#
#      frag_centroid_fractional_position_classifier
# 8004                                   N-terminal
# 8005                                   N-terminal
# 8006                                   N-terminal
# 8007                                   N-terminal
# 8008                                   N-terminal
# ...                                           ...
# 8346                                   C-terminal
# 8347                                   C-terminal
# 8348                                   C-terminal
# 8349                                   C-terminal
# 8350                                   C-terminal
#
# [347 rows x 15 columns]
#                           gene                        fragment ID  \
# 7            EGFP-coding-pEGFP         EGFP-coding-pEGFP_19_108_+
# 14           EGFP-coding-pEGFP         EGFP-coding-pEGFP_22_111_+
# 21           EGFP-coding-pEGFP         EGFP-coding-pEGFP_25_114_+
# 28           EGFP-coding-pEGFP         EGFP-coding-pEGFP_28_117_+
# 35           EGFP-coding-pEGFP         EGFP-coding-pEGFP_31_120_+
# ...                        ...                                ...
# 12046  ssb-coding-EcoliBL21DE3  ssb-coding-EcoliBL21DE3_433_522_+
# 12049  ssb-coding-EcoliBL21DE3  ssb-coding-EcoliBL21DE3_436_525_+
# 12052  ssb-coding-EcoliBL21DE3  ssb-coding-EcoliBL21DE3_439_528_+
# 12056  ssb-coding-EcoliBL21DE3  ssb-coding-EcoliBL21DE3_442_531_+
# 12061  ssb-coding-EcoliBL21DE3  ssb-coding-EcoliBL21DE3_445_534_+
#
#        fragment start (aa)  fragment end (aa)  fragment center (aa)  \
# 7                        7                 36                  21.5
# 14                       8                 37                  22.5
# 21                       9                 38                  23.5
# 28                      10                 39                  24.5
# 35                      11                 40                  25.5
# ...                    ...                ...                   ...
# 12046                  145                174                 159.5
# 12049                  146                175                 160.5
# 12052                  147                176                 161.5
# 12056                  148                177                 162.5
# 12061                  149                178                 163.5
#
#        fragment length (aa)  E = inhibitory effect (enrichment)    sem(E)  \
# 7                        30                            0.119279  0.139890
# 14                       30                           -0.463168  0.163449
# 21                       30                            0.385676  0.146768
# 28                       30                           -0.616033  0.128368
# 35                       30                           -0.193760  0.129166
# ...                     ...                                 ...       ...
# 12046                    30                           -0.924184  0.048997
# 12049                    30                           -0.436107  0.160560
# 12052                    30                            0.508135  0.121051
# 12056                    30                           -0.399455  0.222227
# 12061                    30                           -1.006461  0.140584
#
#       hydrophobicity_KyteDoolittle_classifier  \
# 7                                 hydrophobic
# 14                                hydrophobic
# 21                                hydrophobic
# 28                                hydrophilic
# 35                                hydrophilic
# ...                                       ...
# 12046                             hydrophilic
# 12049                             hydrophilic
# 12052                             hydrophilic
# 12056                             hydrophilic
# 12061                             hydrophilic
#
#       instabIndex_Guruprasad_classifier charge_Lehninger_classifier  \
# 7                                stable                    negative
# 14                               stable                    negative
# 21                               stable                    negative
# 28                               stable                    negative
# 35                               stable                    negative
# ...                                 ...                         ...
# 12046                          unstable                    negative
# 12049                          unstable                    negative
# 12052                          unstable                    negative
# 12056                          unstable                    negative
# 12061                          unstable                    negative
#
#        frag_contains_alphaHelix  frag_contains_betaStrand  frag_contains_Turn  \
# 7                           1.0                       1.0                 0.0
# 14                          1.0                       1.0                 0.0
# 21                          1.0                       1.0                 0.0
# 28                          1.0                       1.0                 0.0
# 35                          1.0                       1.0                 0.0
# ...                         ...                       ...                 ...
# 12046                       0.0                       0.0                 0.0
# 12049                       0.0                       0.0                 0.0
# 12052                       0.0                       0.0                 0.0
# 12056                       0.0                       0.0                 0.0
# 12061                       0.0                       0.0                 0.0
#
#       frag_centroid_fractional_position_classifier
# 7                                       N-terminal
# 14                                      N-terminal
# 21                                      N-terminal
# 28                                      N-terminal
# 35                                      N-terminal
# ...                                            ...
# 12046                                   C-terminal
# 12049                                   C-terminal
# 12052                                   C-terminal
# 12056                                   C-terminal
# 12061                                   C-terminal
#
# [4312 rows x 15 columns]

# %%
inhib_df.groupby('gene').agg(
    aa_start_min=pd.NamedAgg(column='fragment start (aa)',aggfunc='min'),
    aa_start_max=pd.NamedAgg(column='fragment start (aa)',aggfunc='max'),
    aa_stop = pd.NamedAgg(column='fragment end (aa)',aggfunc='max')
).reset_index()
# Out:
#                        gene  aa_start_min  aa_start_max  aa_stop
# 0         EGFP-coding-pEGFP             7           210      239
# 1  folA-coding-EcoliBL21DE3             1           130      159
# 2  ftsZ-coding-EcoliBL21DE3             1           354      383
# 3  groL-coding-EcoliBL21DE3             1           519      548
# 4  groS-coding-EcoliBL21DE3             1            68       97
# 5  gyrA-coding-EcoliBL21DE3             1           843      872
# 6  ileS-coding-EcoliBL21DE3             1           909      938
# 7  rpIL-coding-EcoliBL21DE3             1            92      121
# 8  rpoB-coding-EcoliBL21DE3             1          1313     1342
# 9   ssb-coding-EcoliBL21DE3             1           149      178

# %%
inhib_df_lptg.groupby('gene').agg(
    aa_start_min=pd.NamedAgg(column='fragment start (aa)',aggfunc='min'),
    aa_start_max=pd.NamedAgg(column='fragment start (aa)',aggfunc='max'),
    aa_stop = pd.NamedAgg(column='fragment end (aa)',aggfunc='max')
).reset_index()
# Out:
#                        gene  aa_start_min  aa_start_max  aa_stop
# 0  lptG-coding-EcoliBL21DE3             1           347      360

# %% [markdown]
# ## eGFP

# %%
a3m_path = '/home/gridsan/sswanson/local_code_mirror/ColabFoldCustomMSA/colab_info/egfp/egfp_03e6d.a3m'
name = 'egfp'
protein_range = (7,239)
fragment_start_range = (7,210)
fragment_length = 30

createIndividualMSAsFullLengthFragment(a3m_path,name,protein_range,fragment_start_range,fragment_length)

# %% [markdown]
# ## folA

# %%
a3m_path = '/home/gridsan/sswanson/local_code_mirror/ColabFoldCustomMSA/colab_info/folA/folA_ASversion_e559b.result/folA_ASversion_e559b.a3m'
name = 'folA'
protein_range = (1,159)
fragment_start_range = (7,130)
fragment_length = 30

createIndividualMSAsFullLengthFragment(a3m_path,name,protein_range,fragment_start_range,fragment_length)

# %% [markdown]
# ## ftsZ

# %%
a3m_path = '/home/gridsan/sswanson/local_code_mirror/ColabFoldCustomMSA/colab_info/ftsZ/FtsZ_wholesequence_makemsa_99700.a3m'
name = 'ftsZ'
protein_range = (10,316)
fragment_start_range = (1,354)
fragment_length = 30

createIndividualMSAsFullLengthFragment(a3m_path,name,protein_range,fragment_start_range,fragment_length)

# %%
a3m_path = '/home/gridsan/sswanson/local_code_mirror/ColabFoldCustomMSA/colab_info/ftsZ/FtsZ_wholesequence_makemsa_99700.a3m'
name = 'ftsZ'
protein_range = (10,316)
fragment_start_range = (1,354)
fragment_length = 20

createIndividualMSAsFullLengthFragment(a3m_path,name,protein_range,fragment_start_range,fragment_length)

# %% [markdown]
# ## groeL

# %%
a3m_path = '/home/gridsan/sswanson/local_code_mirror/ColabFoldCustomMSA/colab_info/groeL/groeL_4ee36.result/groeL_4ee36.a3m'
name = 'groEL'
protein_range = (1,548)
fragment_start_range = (1,519)
fragment_length = 30

createIndividualMSAsFullLengthFragment(a3m_path,name,protein_range,fragment_start_range,fragment_length)

# %% [markdown]
# ## groeS

# %%
a3m_path = '/home/gridsan/sswanson/local_code_mirror/ColabFoldCustomMSA/colab_info/groeS/groeS_9afac.result/groeS_9afac.a3m'
name = 'groES'
protein_range = (1,97)
fragment_start_range = (1,68)
fragment_length = 30

createIndividualMSAsFullLengthFragment(a3m_path,name,protein_range,fragment_start_range,fragment_length)
# Out:
# Directory already exists, possibly overwriting existing files

# %% [markdown]
# ## gyrA

# %%
a3m_path = '/home/gridsan/sswanson/local_code_mirror/ColabFoldCustomMSA/colab_info/gyrA/gyrA_99c82.result/gyrA_99c82.a3m'
name = 'gyrA'
protein_range = (1,872)
fragment_start_range = (1,843)
fragment_length = 30

createIndividualMSAsFullLengthFragment(a3m_path,name,protein_range,fragment_start_range,fragment_length)
# Out:
# Directory already exists, possibly overwriting existing files

# %% [markdown]
# ## ileS

# %%
a3m_path = '/home/gridsan/sswanson/local_code_mirror/ColabFoldCustomMSA/colab_info/ileS/ileS_2bda5.a3m'
name = 'gyrA'
protein_range = (1,938)
fragment_start_range = (1,909)
fragment_length = 30

createIndividualMSAsFullLengthFragment(a3m_path,name,protein_range,fragment_start_range,fragment_length)
# Out:
# Directory already exists, possibly overwriting existing files

# %% [markdown]
# ## lptG

# %%
a3m_path = '/home/gridsan/sswanson/local_code_mirror/ColabFoldCustomMSA/colab_info/lptG/lptG_ae86a.result/lptG_ae86a.a3m'
name = 'lptG'
protein_range = (1,360)
fragment_start_range = (1,347)
fragment_length = 14

createIndividualMSAsFullLengthFragment(a3m_path,name,protein_range,fragment_start_range,fragment_length)

# %% [markdown]
# ## rplL

# %%
a3m_path = '/home/gridsan/sswanson/local_code_mirror/ColabFoldCustomMSA/colab_info/rplL/rpIL_fullength_7c4cd.a3m'
name = 'rplL'
protein_range = (1,121)
fragment_start_range = (1,92)
fragment_length = 30

createIndividualMSAsFullLengthFragment(a3m_path,name,protein_range,fragment_start_range,fragment_length)
# Out:
# Directory already exists, possibly overwriting existing files

# %% [markdown]
# ## rpoB

# %%
a3m_path = '/home/gridsan/sswanson/local_code_mirror/ColabFoldCustomMSA/colab_info/rpoB/rpoB_2bda5.a3m'
name = 'rpoB'
protein_range = (1,1342)
fragment_start_range = (1,1313)
fragment_length = 30

createIndividualMSAsFullLengthFragment(a3m_path,name,protein_range,fragment_start_range,fragment_length)
# Out:
# Directory already exists, possibly overwriting existing files

# %% [markdown]
# ## ssB

# %%
a3m_path = '/home/gridsan/sswanson/local_code_mirror/ColabFoldCustomMSA/colab_info/ssb/ssb_8fe71.a3m'
name = 'ssb'
protein_range = (1,178)
fragment_start_range = (1,149)
fragment_length = 30

createIndividualMSAsFullLengthFragment(a3m_path,name,protein_range,fragment_start_range,fragment_length)
