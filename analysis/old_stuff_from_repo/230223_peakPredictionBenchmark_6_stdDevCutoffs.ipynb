# %%
# %matplotlib inline

import glob, json, argparse, os, sys
import string

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import scipy

from Bio.PDB import *

sys.path.insert(0,'/data1/groups/keatinglab/swans/savinovCollaboration/inhibitory_fragments_structure_prediction')
from src.colabfold_process_output_utils import *
from src.colabfold_process_output import *
from src.analyze_predictions import *
from src.peak_prediction import *

# %% [markdown]
# # Import data

# %% [markdown]
# ## Experimental peaks

# %%
path = '/data1/groups/keatinglab/swans/savinovCollaboration/analysis/230223_expPeakFinding_5/230223_experimentalpeaks_variablecutoff_modeabsolute_grouping25_maxgapdistance5.csv'
exp_df = pd.read_csv(path,index_col=0)
exp_df['gene'] = exp_df['gene'].str.replace('rpIL-coding-EcoliBL21DE3','rplL-coding-EcoliBL21DE3') # fix misnamed gene
print(len(exp_df))
exp_df.head(15)
# Out:
# 95
#     fragment center (aa)  peak region first fragment center (aa)  \
# 0                   40.5                                    40.5
# 1                   58.5                                    53.5
# 2                  148.5                                   148.5
# 3                   16.5                                    15.5
# 4                   32.5                                    32.5
# 5                   72.5                                    70.5
# 6                   90.5                                    88.5
# 7                  101.5                                   101.5
# 8                  125.5                                   111.5
# 9                  142.5                                   139.5
# 10                  26.5                                    26.5
# 11                 130.5                                   130.5
# 12                 174.5                                   163.5
# 13                 190.5                                   187.5
# 14                 213.5                                   211.5
#
#     peak region last fragment center (aa)  peak_fragment_score  \
# 0                                    40.5            -2.387241
# 1                                    58.5            -2.527368
# 2                                   154.5            -2.959939
# 3                                    17.5            -5.935952
# 4                                    32.5            -3.076845
# 5                                    72.5            -3.155299
# 6                                    90.5            -3.180808
# 7                                   101.5            -2.920198
# 8                                   125.5            -5.570582
# 9                                   142.5            -4.365602
# 10                                   26.5            -2.527031
# 11                                  135.5            -4.585132
# 12                                  186.5            -9.531838
# 13                                  210.5            -5.988661
# 14                                  214.5            -5.157780
#
#                         gene                         fragment ID  \
# 0          EGFP-coding-pEGFP          EGFP-coding-pEGFP_76_165_+
# 1          EGFP-coding-pEGFP         EGFP-coding-pEGFP_130_219_+
# 2          EGFP-coding-pEGFP         EGFP-coding-pEGFP_400_489_+
# 3   folA-coding-EcoliBL21DE3     folA-coding-EcoliBL21DE3_4_93_+
# 4   folA-coding-EcoliBL21DE3   folA-coding-EcoliBL21DE3_52_141_+
# 5   folA-coding-EcoliBL21DE3  folA-coding-EcoliBL21DE3_172_261_+
# 6   folA-coding-EcoliBL21DE3  folA-coding-EcoliBL21DE3_226_315_+
# 7   folA-coding-EcoliBL21DE3  folA-coding-EcoliBL21DE3_259_348_+
# 8   folA-coding-EcoliBL21DE3  folA-coding-EcoliBL21DE3_331_420_+
# 9   folA-coding-EcoliBL21DE3  folA-coding-EcoliBL21DE3_382_471_+
# 10  ftsZ-coding-EcoliBL21DE3   ftsZ-coding-EcoliBL21DE3_34_123_+
# 11  ftsZ-coding-EcoliBL21DE3  ftsZ-coding-EcoliBL21DE3_346_435_+
# 12  ftsZ-coding-EcoliBL21DE3  ftsZ-coding-EcoliBL21DE3_478_567_+
# 13  ftsZ-coding-EcoliBL21DE3  ftsZ-coding-EcoliBL21DE3_526_615_+
# 14  ftsZ-coding-EcoliBL21DE3  ftsZ-coding-EcoliBL21DE3_595_684_+
#
#     fragment start (aa)  fragment end (aa)  fragment length (aa)  \
# 0                    26                 55                    30
# 1                    44                 73                    30
# 2                   134                163                    30
# 3                     2                 31                    30
# 4                    18                 47                    30
# 5                    58                 87                    30
# 6                    76                105                    30
# 7                    87                116                    30
# 8                   111                140                    30
# 9                   128                157                    30
# 10                   12                 41                    30
# 11                  116                145                    30
# 12                  160                189                    30
# 13                  176                205                    30
# 14                  199                228                    30
#
#     E = inhibitory effect (enrichment)    sem(E)  \
# 0                            -2.387241  0.512188
# 1                            -2.527368  0.269506
# 2                            -2.959939  0.433318
# 3                            -5.935952  0.457483
# 4                            -3.076845  1.075402
# 5                            -3.155299  1.427395
# 6                            -3.180808  0.439261
# 7                            -2.920198  1.263917
# 8                            -5.570582  0.854611
# 9                            -4.365602  1.292585
# 10                           -2.527031  0.350486
# 11                           -4.585132  1.284617
# 12                           -9.531838  1.005946
# 13                           -5.988661  1.474587
# 14                           -5.157780  1.209352
#
#    hydrophobicity_KyteDoolittle_classifier instabIndex_Guruprasad_classifier  \
# 0                              hydrophilic                            stable
# 1                              hydrophobic                            stable
# 2                              hydrophilic                            stable
# 3                              hydrophobic                            stable
# 4                              hydrophilic                          unstable
# 5                              hydrophilic                          unstable
# 6                              hydrophobic                          unstable
# 7                              hydrophilic                          unstable
# 8                              hydrophilic                            stable
# 9                              hydrophilic                            stable
# 10                             hydrophobic                            stable
# 11                             hydrophobic                            stable
# 12                             hydrophobic                            stable
# 13                             hydrophobic                            stable
# 14                             hydrophobic                            stable
#
#    charge_Lehninger_classifier  frag_contains_alphaHelix  \
# 0                     positive                       1.0
# 1                     positive                       1.0
# 2                     positive                       0.0
# 3                     negative                       1.0
# 4                     positive                       1.0
# 5                     negative                       1.0
# 6                     negative                       1.0
# 7                      neutral                       1.0
# 8                     negative                       1.0
# 9                     negative                       1.0
# 10                     neutral                       1.0
# 11                    positive                       1.0
# 12                     neutral                       1.0
# 13                     neutral                       1.0
# 14                    negative                       1.0
#
#     frag_contains_betaStrand  frag_contains_Turn  \
# 0                        1.0                 0.0
# 1                        1.0                 1.0
# 2                        1.0                 1.0
# 3                        1.0                 1.0
# 4                        1.0                 1.0
# 5                        1.0                 0.0
# 6                        1.0                 0.0
# 7                        1.0                 0.0
# 8                        1.0                 0.0
# 9                        1.0                 0.0
# 10                       1.0                 0.0
# 11                       1.0                 0.0
# 12                       1.0                 0.0
# 13                       0.0                 0.0
# 14                       1.0                 0.0
#
#    frag_centroid_fractional_position_classifier  inhib_effect_cutoff
# 0                                    N-terminal            -2.123634
# 1                                    N-terminal            -2.123634
# 2                                       central            -2.123634
# 3                                    N-terminal            -2.780845
# 4                                    N-terminal            -2.780845
# 5                                       central            -2.780845
# 6                                       central            -2.780845
# 7                                       central            -2.780845
# 8                                    C-terminal            -2.780845
# 9                                    C-terminal            -2.780845
# 10                                   N-terminal            -2.289215
# 11                                      central            -2.289215
# 12                                      central            -2.289215
# 13                                      central            -2.289215
# 14                                      central            -2.289215

# %% [markdown]
# Would like to know how many of these peaks are "new", e.g. not in the set that Andrew curated. Load the table of curated peaks and label these as "novel" if not close to those peaks

# %%
path = '/data1/groups/keatinglab/swans/savinovCollaboration/inhibitory_fragments_structure_prediction/data/PPI_inhibitory_fragment_peaks_AS_230114.csv'
andrew_df = pd.read_csv(path)
print(len(andrew_df))
andrew_df.head(20)
# Out:
# 19
#    protein-coding gene  \
# 0                 gyrA
# 1                 gyrA
# 2                 ftsZ
# 3                 ftsZ
# 4                 ftsZ
# 5                 ftsZ
# 6                 ftsZ
# 7                 rplL
# 8                 rplL
# 9                  ssb
# 10                 ssb
# 11                 ssb
# 12                groL
# 13                groL
# 14                groL
# 15                groL
# 16                groL
# 17                groL
# 18                lptG
#
#     protein-protein interaction inhibitory peak center (aa)  \
# 0                                                26.5
# 1                                               385.5
# 2                                               130.5
# 3                                               177.5
# 4                                               200.5
# 5                                               272.5
# 6                                               367.5
# 7                                                19.5
# 8                                                19.5
# 9                                                66.5
# 10                                               66.5
# 11                                               66.5
# 12                                               17.5
# 13                                              101.5
# 14                                              243.5
# 15                                              260.5
# 16                                              445.5
# 17                                              500.5
# 18                                              323.5
#
#     30 aa fragment start (aa)  30 aa fragment end (aa)  \
# 0                          12                       41
# 1                         371                      400
# 2                         116                      145
# 3                         163                      192
# 4                         186                      215
# 5                         258                      287
# 6                         353                      382
# 7                           5                       34
# 8                           5                       34
# 9                          52                       81
# 10                         52                       81
# 11                         52                       81
# 12                          3                       32
# 13                         87                      116
# 14                        229                      258
# 15                        246                      275
# 16                        431                      460
# 17                        486                      515
# 18                        309                      338
#
#    protein-protein interaction partner gene(s) Experimental structure name  \
# 0                                         gyrB    6rks_gyrA_AC_gyrB_BD.pdb
# 1                                         gyrA    6rks_gyrA_AC_gyrB_BD.pdb
# 2                                         ftsZ           6unx_ftsZ_ABC.pdb
# 3                                         ftsZ           6unx_ftsZ_ABC.pdb
# 4                                         ftsZ           6unx_ftsZ_ABC.pdb
# 5                                         ftsZ           6unx_ftsZ_ABC.pdb
# 6                       ftsZ, ftsA, zipA, minC                         NaN
# 7                                         rplJ      3j7z_rplL_6_rplJ_5.pdb
# 8                                         rplL            1rqu_rplL_AB.pdb
# 9                                          ssb           1eqq_ssb_ABCD.pdb
# 10                                  ssb2copies           1eqq_ssb_ABCD.pdb
# 11                                  ssb4copies           1eqq_ssb_ABCD.pdb
# 12                                        groL    1aon_groEL_POUBAGHNM.pdb
# 13                                        groL    1aon_groEL_POUBAGHNM.pdb
# 14                                        groS    1aon_groEL_POUBAGHNM.pdb
# 15                                        groS    1aon_groEL_POUBAGHNM.pdb
# 16                                        groL    1aon_groEL_POUBAGHNM.pdb
# 17                                        groL    1aon_groEL_POUBAGHNM.pdb
# 18                                        lptF      6mi7_lptG_G_lptF_F.pdb
#
#    Protein chain in structure Fragment chain in structure  \
# 0                           B                           A
# 1                           C                           A
# 2                           B                           A
# 3                           B                           A
# 4                           C                           A
# 5                           C                           A
# 6                           ?                           A
# 7                           5                           6
# 8                           A                           C
# 9                           A                           C
# 10                          A                           C
# 11                          A                           C
# 12                        B,G                           A
# 13                        B,H                           A
# 14                          O                           A
# 15                        O,G                           A
# 16                          ?                           A
# 17                          B                           A
# 18                          F                           G
#
#    overlap with Ncontacts peak?  Ncontacts peak center Overlap degree (aa)  \
# 0                         (TBD)                    NaN                 NaN
# 1                           yes                  385.5                  30
# 2                           yes                  129.5     30 (broad peak)
# 3                           yes                  176.5     30 (broad peak)
# 4                           yes                  201.5     30 (broad peak)
# 5                           yes                  271.5     30 (broad peak)
# 6                    yes (ftsZ)                  366.5                  29
# 7                    yes (rpIL)                   19.5                  30
# 8                    yes (rpIL)                   19.5                  30
# 9             yes (ssb, 1 copy)                   71.5                  25
# 10          yes (ssb, 2 copies)                   75.5                  21
# 11          yes (ssb, 4 copies)                   74.5                  22
# 12           yes (groL, 1 copy)                   15.5                  28
# 13           yes (groL, 1 copy)                  106.5                  25
# 14           yes (groS, 1 copy)                  252.5                  21
# 15           yes (groS, 1 copy)                  260.5                  30
# 16           yes (groL, 1 copy)                  464.5                  11
# 17           yes (groL, 1 copy)                  514.5                  16
# 18                        (TBD)                    NaN                 NaN
#
#     Ncontacts value  weighted contacts peak center  weighted contacts value  \
# 0               NaN                            NaN                      NaN
# 1               3.0                          386.5                      2.6
# 2               4.0                          129.5                      2.3
# 3               8.0                          176.5                      6.3
# 4              15.0                          201.5                     11.7
# 5               8.0                          271.5                      6.3
# 6              12.0                          366.5                      3.3
# 7              10.0                           19.5                      2.8
# 8              10.0                           19.5                      2.8
# 9               6.0                           71.5                      4.9
# 10              3.0                           75.5                      2.1
# 11             11.0                           74.5                      7.4
# 12              5.0                           15.5                      4.4
# 13              5.0                          106.5                      4.3
# 14             10.0                          252.5                      4.0
# 15              8.0                          260.5                      5.1
# 16              2.0                          464.5                      1.6
# 17             16.0                          514.5                     14.0
# 18              NaN                            NaN                      NaN
#
#                                                 notes
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6   no structural data; intrinsically disordered t...
# 7                                                 NaN
# 8   both a homomeric (with rplL) and heteromeric i...
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12  maps to GroEL homomeric heptamer-heptamer inte...
# 13  maps to GroEL homomeric heptamer-heptamer inte...
# 14      maps to GroEL ring interface with GroES ring
# 15      maps to GroEL ring interface with GroES ring
# 16  maps to GroEL homomeric heptamer-heptamer inte...
# 17  maps to GroEL homomeric heptamer-heptamer inte...
# 18  as in Fig 2H inset, this (TM5) peak maps to a ...

# %%
andrew_df[andrew_df['protein-coding gene']=='rplL']
# Out:
#   protein-coding gene  \
# 7                rplL
# 8                rplL
#
#    protein-protein interaction inhibitory peak center (aa)  \
# 7                                               19.5
# 8                                               19.5
#
#    30 aa fragment start (aa)  30 aa fragment end (aa)  \
# 7                          5                       34
# 8                          5                       34
#
#   protein-protein interaction partner gene(s) Experimental structure name  \
# 7                                        rplJ      3j7z_rplL_6_rplJ_5.pdb
# 8                                        rplL            1rqu_rplL_AB.pdb
#
#   Protein chain in structure Fragment chain in structure  \
# 7                          5                           6
# 8                          A                           C
#
#   overlap with Ncontacts peak?  Ncontacts peak center Overlap degree (aa)  \
# 7                   yes (rpIL)                   19.5                  30
# 8                   yes (rpIL)                   19.5                  30
#
#    Ncontacts value  weighted contacts peak center  weighted contacts value  \
# 7             10.0                           19.5                      2.8
# 8             10.0                           19.5                      2.8
#
#                                                notes
# 7                                                NaN
# 8  both a homomeric (with rplL) and heteromeric i...

# %%
# Go through the experimental peaks df and check if each peak is similar to one already in the curated set
peak_type = []
for i,row in exp_df.iterrows():
    gene = row['gene'].split('-')[0]
    peak_start = row['peak region first fragment center (aa)']
    peak_end = row['peak region last fragment center (aa)']
    filt_df = andrew_df[(andrew_df['protein-coding gene']==gene)&
                        (andrew_df['protein-protein interaction inhibitory peak center (aa)']>=peak_start)&
                        (andrew_df['protein-protein interaction inhibitory peak center (aa)']<=peak_end)]
    if len(filt_df) > 0:
        print("Fragment is in curated set")
        peak_type.append('known')
    else:
        peak_type.append('novel')
exp_df['peak type'] = peak_type
exp_df.groupby('peak type').size()
# Out:
# Fragment is in curated set
# Fragment is in curated set
# Fragment is in curated set
# Fragment is in curated set
# Fragment is in curated set
# Fragment is in curated set
# Fragment is in curated set
# Fragment is in curated set
# Fragment is in curated set
# Fragment is in curated set
# Fragment is in curated set
# Fragment is in curated set
# Fragment is in curated set
# peak type
# known    13
# novel    82
# dtype: int64

# %%
andrew_df[(andrew_df['protein-coding gene']=='rplL')&
          (andrew_df['protein-protein interaction inhibitory peak center (aa)']>15.5)&
          (andrew_df['protein-protein interaction inhibitory peak center (aa)']<=31.5)]
# Out:
#   protein-coding gene  \
# 7                rplL
# 8                rplL
#
#    protein-protein interaction inhibitory peak center (aa)  \
# 7                                               19.5
# 8                                               19.5
#
#    30 aa fragment start (aa)  30 aa fragment end (aa)  \
# 7                          5                       34
# 8                          5                       34
#
#   protein-protein interaction partner gene(s) Experimental structure name  \
# 7                                        rplJ      3j7z_rplL_6_rplJ_5.pdb
# 8                                        rplL            1rqu_rplL_AB.pdb
#
#   Protein chain in structure Fragment chain in structure  \
# 7                          5                           6
# 8                          A                           C
#
#   overlap with Ncontacts peak?  Ncontacts peak center Overlap degree (aa)  \
# 7                   yes (rpIL)                   19.5                  30
# 8                   yes (rpIL)                   19.5                  30
#
#    Ncontacts value  weighted contacts peak center  weighted contacts value  \
# 7             10.0                           19.5                      2.8
# 8             10.0                           19.5                      2.8
#
#                                                notes
# 7                                                NaN
# 8  both a homomeric (with rplL) and heteromeric i...

# %% [markdown]
# ## Predicted peaks (alphafold)

# %%
path = '/data1/groups/keatinglab/swans/savinovCollaboration/analysis/230214_peakPrediction_4/230223_alphafoldfragment_predictions.csv'
pred_df = pd.read_csv(path,index_col=0)
pred_df['gene'] = pred_df['gene'].str.replace('rpIL-coding-EcoliBL21DE3','rplL-coding-EcoliBL21DE3') # fix misnamed gene
print(len(pred_df))
pred_df.head()
# Out:
# 202
#                 fragment_name  fragment start (aa)  fragment center (aa)  \
# 28      folA_1-159_folA_35-64                   35                  49.5
# 85     folA_1-159_folA_92-121                   92                 106.5
# 125     FtsZ_10-316_FtsZ_2-31                    2                  16.5
# 166    FtsZ_10-316_FtsZ_43-72                   43                  57.5
# 289  FtsZ_10-316_FtsZ_166-195                  166                 180.5
#
#      fragment end (aa)      iptm      plddt  n_contacts  \
# 28                  64  0.481738  87.872333           7
# 85                 121  0.487784  86.148333           7
# 125                 31  0.539908  82.679000           6
# 166                 72  0.700501  88.043333          10
# 289                195  0.802524  88.135333           9
#
#                                                   path _merge  \
# 28   /data1/groups/keatinglab/swans/savinovCollabor...   both
# 85   /data1/groups/keatinglab/swans/savinovCollabor...   both
# 125  /data1/groups/keatinglab/swans/savinovCollabor...   both
# 166  /data1/groups/keatinglab/swans/savinovCollabor...   both
# 289  /data1/groups/keatinglab/swans/savinovCollabor...   both
#
#      weighted_contacts  ... charge_Lehninger_classifier  \
# 28            3.372169  ...                         NaN
# 85            3.414489  ...                     neutral
# 125           3.239451  ...                    negative
# 166           7.005011  ...                    positive
# 289           7.222718  ...                     neutral
#
#     frag_contains_alphaHelix frag_contains_betaStrand  frag_contains_Turn  \
# 28                       NaN                      NaN                 NaN
# 85                       1.0                      1.0                 0.0
# 125                      1.0                      1.0                 0.0
# 166                      1.0                      1.0                 0.0
# 289                      1.0                      0.0                 0.0
#
#      frag_centroid_fractional_position_classifier  \
# 28                                            NaN
# 85                                     C-terminal
# 125                                    N-terminal
# 166                                    N-terminal
# 289                                       central
#
#                                            contact_set cluster cluster_size  \
# 28   [(<Residue PHE het=  resseq=140 icode= >, <Res...       1            1
# 85   [(<Residue PRO het=  resseq=130 icode= >, <Res...       2            1
# 125  [(<Residue ARG het=  resseq=41 icode= >, <Resi...       7            1
# 166  [(<Residue ALA het=  resseq=2 icode= >, <Resid...       6           16
# 289  [(<Residue LEU het=  resseq=263 icode= >, <Res...       5           22
#
#     cluster first fragment center (aa)  cluster last fragment center (aa)
# 28                                49.5                               49.5
# 85                               106.5                              106.5
# 125                               16.5                               16.5
# 166                               54.5                               80.5
# 289                              164.5                              186.5
#
# [5 rows x 28 columns]

# %%
pred_df.keys()
# Out:
# Index(['fragment_name', 'fragment start (aa)', 'fragment center (aa)',
#        'fragment end (aa)', 'iptm', 'plddt', 'n_contacts', 'path', '_merge',
#        'weighted_contacts', 'gene', 'condition', 'fragment ID',
#        'fragment length (aa)', 'E = inhibitory effect (enrichment)', 'sem(E)',
#        'hydrophobicity_KyteDoolittle_classifier',
#        'instabIndex_Guruprasad_classifier', 'charge_Lehninger_classifier',
#        'frag_contains_alphaHelix', 'frag_contains_betaStrand',
#        'frag_contains_Turn', 'frag_centroid_fractional_position_classifier',
#        'contact_set', 'cluster', 'cluster_size',
#        'cluster first fragment center (aa)',
#        'cluster last fragment center (aa)'],
#       dtype='object')

# %% [markdown]
# # Novel peak prediction

# %% [markdown]
# Of the experimentally determined fragments for which there is no known structural evidence, which have a binding structure predicted by alphafold?

# %%
exp_df.gene.unique()
# Out:
# array(['EGFP-coding-pEGFP', 'folA-coding-EcoliBL21DE3',
#        'ftsZ-coding-EcoliBL21DE3', 'groL-coding-EcoliBL21DE3',
#        'gyrA-coding-EcoliBL21DE3', 'ileS-coding-EcoliBL21DE3',
#        'lptG-coding-EcoliBL21DE3', 'rplL-coding-EcoliBL21DE3',
#        'rpoB-coding-EcoliBL21DE3', 'ssb-coding-EcoliBL21DE3'],
#       dtype=object)

# %%
pred_df.gene.unique()
# Out:
# array(['folA-coding-EcoliBL21DE3', 'ftsZ-coding-EcoliBL21DE3',
#        'groL-coding-EcoliBL21DE3', 'gyrA-coding-EcoliBL21DE3',
#        'lptG-coding-EcoliBL21DE3', 'rplL-coding-EcoliBL21DE3',
#        'ssb-coding-EcoliBL21DE3'], dtype=object)

# %%
pred_df.condition.unique()
# Out:
# array(['30aa_monomer_folA', '30aa_monomer_fstZ', '30aa_dimer_groL',
#        '30aa_monomer_groL', '30aa_monomer_groS', '30aa_monomer_gyrA',
#        '30aa_monomer_gyrB', '30aa_monomer_lptF', '30aa_monomer_lptG',
#        '30aa_monomer_rplL', '30aa_dimer_ssb', '30aa_monomer_ssb',
#        '30aa_tetramer_ssb'], dtype=object)

# %%
benchmark_genes = {
    'folA-coding-EcoliBL21DE3',
    'ftsZ-coding-EcoliBL21DE3',
    'groL-coding-EcoliBL21DE3',
    'gyrA-coding-EcoliBL21DE3',
    'lptG-coding-EcoliBL21DE3',
    'rplL-coding-EcoliBL21DE3',
    'ssb-coding-EcoliBL21DE3'
}
benchmark_conditions = {
    '30aa_monomer_folA', '30aa_monomer_fstZ',
    '30aa_monomer_groL', '30aa_monomer_groS', '30aa_monomer_gyrA',
    '30aa_monomer_gyrB', '30aa_monomer_rplL', '30aa_dimer_ssb',
    '30aa_monomer_ssb'
}

# %% [markdown]
# An experimental inhibitory fragment is predicted by alphafold if the representative fragment (i.e. the fragment with the highest inhibitory effect in the peak) is within the range of the alphafold peak cluster

# %%
pred_df.columns
# Out:
# Index(['fragment_name', 'fragment start (aa)', 'fragment center (aa)',
#        'fragment end (aa)', 'iptm', 'plddt', 'n_contacts', 'path', '_merge',
#        'weighted_contacts', 'gene', 'condition', 'fragment ID',
#        'fragment length (aa)', 'E = inhibitory effect (enrichment)', 'sem(E)',
#        'hydrophobicity_KyteDoolittle_classifier',
#        'instabIndex_Guruprasad_classifier', 'charge_Lehninger_classifier',
#        'frag_contains_alphaHelix', 'frag_contains_betaStrand',
#        'frag_contains_Turn', 'frag_centroid_fractional_position_classifier',
#        'contact_set', 'cluster', 'cluster_size',
#        'cluster first fragment center (aa)',
#        'cluster last fragment center (aa)'],
#       dtype='object')

# %%
# experimental peak is covered if the center (fragment with max inhib effect)
# is within the range of the alphafold predictions

exp_filt_df = exp_df[(exp_df['gene'].isin(benchmark_genes))&(exp_df['peak type']=='novel')].copy(deep=True)
pred_filt_df = pred_df[pred_df['condition'].isin(benchmark_conditions)]
print(f"{len(exp_filt_df)} experimental peaks and {len(pred_filt_df)} predicted")
count,covered = 0,0
covering_list = []
covered_list = []
for i,row in exp_filt_df.iterrows():
    print(row['gene'],row['fragment center (aa)'])
    frag_center_aa = row['fragment center (aa)']
    pred_covered = pred_df[(frag_center_aa>=pred_df['cluster first fragment center (aa)'])&
                        (frag_center_aa<=pred_df['cluster last fragment center (aa)'])&
                        (pred_df['gene']==row['gene'])]
    print(len(pred_covered))
    display(pred_covered.head(5))
    covering_list.append(list(pred_covered['fragment_name']))
    covered_list.append(True if len(pred_covered['fragment_name'])>0 else False)
    if len(pred_covered) > 0:
        covered += 1
    count += 1

exp_filt_df['covering'] = covering_list
exp_filt_df['covered'] = covered_list
print(f"{count} experimental fragments with significant inhibition and {covered} overlapping alphafold predictions")
# Out:
# 26 experimental peaks and 78 predicted
# folA-coding-EcoliBL21DE3 16.5
# 0
# Empty DataFrame
# Columns: [fragment_name, fragment start (aa), fragment center (aa), fragment end (aa), iptm, plddt, n_contacts, path, _merge, weighted_contacts, gene, condition, fragment ID, fragment length (aa), E = inhibitory effect (enrichment), sem(E), hydrophobicity_KyteDoolittle_classifier, instabIndex_Guruprasad_classifier, charge_Lehninger_classifier, frag_contains_alphaHelix, frag_contains_betaStrand, frag_contains_Turn, frag_centroid_fractional_position_classifier, contact_set, cluster, cluster_size, cluster first fragment center (aa), cluster last fragment center (aa)]
# Index: []
#
# [0 rows x 28 columns]
# folA-coding-EcoliBL21DE3 32.5
# 0
# Empty DataFrame
# Columns: [fragment_name, fragment start (aa), fragment center (aa), fragment end (aa), iptm, plddt, n_contacts, path, _merge, weighted_contacts, gene, condition, fragment ID, fragment length (aa), E = inhibitory effect (enrichment), sem(E), hydrophobicity_KyteDoolittle_classifier, instabIndex_Guruprasad_classifier, charge_Lehninger_classifier, frag_contains_alphaHelix, frag_contains_betaStrand, frag_contains_Turn, frag_centroid_fractional_position_classifier, contact_set, cluster, cluster_size, cluster first fragment center (aa), cluster last fragment center (aa)]
# Index: []
#
# [0 rows x 28 columns]
# folA-coding-EcoliBL21DE3 72.5
# 0
# Empty DataFrame
# Columns: [fragment_name, fragment start (aa), fragment center (aa), fragment end (aa), iptm, plddt, n_contacts, path, _merge, weighted_contacts, gene, condition, fragment ID, fragment length (aa), E = inhibitory effect (enrichment), sem(E), hydrophobicity_KyteDoolittle_classifier, instabIndex_Guruprasad_classifier, charge_Lehninger_classifier, frag_contains_alphaHelix, frag_contains_betaStrand, frag_contains_Turn, frag_centroid_fractional_position_classifier, contact_set, cluster, cluster_size, cluster first fragment center (aa), cluster last fragment center (aa)]
# Index: []
#
# [0 rows x 28 columns]
# folA-coding-EcoliBL21DE3 90.5
# 0
# Empty DataFrame
# Columns: [fragment_name, fragment start (aa), fragment center (aa), fragment end (aa), iptm, plddt, n_contacts, path, _merge, weighted_contacts, gene, condition, fragment ID, fragment length (aa), E = inhibitory effect (enrichment), sem(E), hydrophobicity_KyteDoolittle_classifier, instabIndex_Guruprasad_classifier, charge_Lehninger_classifier, frag_contains_alphaHelix, frag_contains_betaStrand, frag_contains_Turn, frag_centroid_fractional_position_classifier, contact_set, cluster, cluster_size, cluster first fragment center (aa), cluster last fragment center (aa)]
# Index: []
#
# [0 rows x 28 columns]
# folA-coding-EcoliBL21DE3 101.5
# 0
# Empty DataFrame
# Columns: [fragment_name, fragment start (aa), fragment center (aa), fragment end (aa), iptm, plddt, n_contacts, path, _merge, weighted_contacts, gene, condition, fragment ID, fragment length (aa), E = inhibitory effect (enrichment), sem(E), hydrophobicity_KyteDoolittle_classifier, instabIndex_Guruprasad_classifier, charge_Lehninger_classifier, frag_contains_alphaHelix, frag_contains_betaStrand, frag_contains_Turn, frag_centroid_fractional_position_classifier, contact_set, cluster, cluster_size, cluster first fragment center (aa), cluster last fragment center (aa)]
# Index: []
#
# [0 rows x 28 columns]
# folA-coding-EcoliBL21DE3 125.5
# 0
# Empty DataFrame
# Columns: [fragment_name, fragment start (aa), fragment center (aa), fragment end (aa), iptm, plddt, n_contacts, path, _merge, weighted_contacts, gene, condition, fragment ID, fragment length (aa), E = inhibitory effect (enrichment), sem(E), hydrophobicity_KyteDoolittle_classifier, instabIndex_Guruprasad_classifier, charge_Lehninger_classifier, frag_contains_alphaHelix, frag_contains_betaStrand, frag_contains_Turn, frag_centroid_fractional_position_classifier, contact_set, cluster, cluster_size, cluster first fragment center (aa), cluster last fragment center (aa)]
# Index: []
#
# [0 rows x 28 columns]
# folA-coding-EcoliBL21DE3 142.5
# 0
# Empty DataFrame
# Columns: [fragment_name, fragment start (aa), fragment center (aa), fragment end (aa), iptm, plddt, n_contacts, path, _merge, weighted_contacts, gene, condition, fragment ID, fragment length (aa), E = inhibitory effect (enrichment), sem(E), hydrophobicity_KyteDoolittle_classifier, instabIndex_Guruprasad_classifier, charge_Lehninger_classifier, frag_contains_alphaHelix, frag_contains_betaStrand, frag_contains_Turn, frag_centroid_fractional_position_classifier, contact_set, cluster, cluster_size, cluster first fragment center (aa), cluster last fragment center (aa)]
# Index: []
#
# [0 rows x 28 columns]
# ftsZ-coding-EcoliBL21DE3 26.5
# 0
# Empty DataFrame
# Columns: [fragment_name, fragment start (aa), fragment center (aa), fragment end (aa), iptm, plddt, n_contacts, path, _merge, weighted_contacts, gene, condition, fragment ID, fragment length (aa), E = inhibitory effect (enrichment), sem(E), hydrophobicity_KyteDoolittle_classifier, instabIndex_Guruprasad_classifier, charge_Lehninger_classifier, frag_contains_alphaHelix, frag_contains_betaStrand, frag_contains_Turn, frag_centroid_fractional_position_classifier, contact_set, cluster, cluster_size, cluster first fragment center (aa), cluster last fragment center (aa)]
# Index: []
#
# [0 rows x 28 columns]
# ftsZ-coding-EcoliBL21DE3 213.5
# 1
#                 fragment_name  fragment start (aa)  fragment center (aa)  \
# 310  FtsZ_10-316_FtsZ_187-216                  187                 201.5
#
#      fragment end (aa)      iptm      plddt  n_contacts  \
# 310                216  0.780989  85.832333          15
#
#                                                   path _merge  \
# 310  /data1/groups/keatinglab/swans/savinovCollabor...   both
#
#      weighted_contacts  ... charge_Lehninger_classifier  \
# 310          11.714832  ...                     neutral
#
#     frag_contains_alphaHelix frag_contains_betaStrand  frag_contains_Turn  \
# 310                      1.0                      0.0                 0.0
#
#      frag_centroid_fractional_position_classifier  \
# 310                                       central
#
#                                            contact_set cluster cluster_size  \
# 310  [(<Residue GLY het=  resseq=62 icode= >, <Resi...       4           28
#
#     cluster first fragment center (aa)  cluster last fragment center (aa)
# 310                              195.5                              222.5
#
# [1 rows x 28 columns]
# groL-coding-EcoliBL21DE3 175.5
# 0
# Empty DataFrame
# Columns: [fragment_name, fragment start (aa), fragment center (aa), fragment end (aa), iptm, plddt, n_contacts, path, _merge, weighted_contacts, gene, condition, fragment ID, fragment length (aa), E = inhibitory effect (enrichment), sem(E), hydrophobicity_KyteDoolittle_classifier, instabIndex_Guruprasad_classifier, charge_Lehninger_classifier, frag_contains_alphaHelix, frag_contains_betaStrand, frag_contains_Turn, frag_centroid_fractional_position_classifier, contact_set, cluster, cluster_size, cluster first fragment center (aa), cluster last fragment center (aa)]
# Index: []
#
# [0 rows x 28 columns]
# groL-coding-EcoliBL21DE3 185.5
# 0
# Empty DataFrame
# Columns: [fragment_name, fragment start (aa), fragment center (aa), fragment end (aa), iptm, plddt, n_contacts, path, _merge, weighted_contacts, gene, condition, fragment ID, fragment length (aa), E = inhibitory effect (enrichment), sem(E), hydrophobicity_KyteDoolittle_classifier, instabIndex_Guruprasad_classifier, charge_Lehninger_classifier, frag_contains_alphaHelix, frag_contains_betaStrand, frag_contains_Turn, frag_centroid_fractional_position_classifier, contact_set, cluster, cluster_size, cluster first fragment center (aa), cluster last fragment center (aa)]
# Index: []
#
# [0 rows x 28 columns]
# gyrA-coding-EcoliBL21DE3 89.5
# 0
# Empty DataFrame
# Columns: [fragment_name, fragment start (aa), fragment center (aa), fragment end (aa), iptm, plddt, n_contacts, path, _merge, weighted_contacts, gene, condition, fragment ID, fragment length (aa), E = inhibitory effect (enrichment), sem(E), hydrophobicity_KyteDoolittle_classifier, instabIndex_Guruprasad_classifier, charge_Lehninger_classifier, frag_contains_alphaHelix, frag_contains_betaStrand, frag_contains_Turn, frag_centroid_fractional_position_classifier, contact_set, cluster, cluster_size, cluster first fragment center (aa), cluster last fragment center (aa)]
# Index: []
#
# [0 rows x 28 columns]
# gyrA-coding-EcoliBL21DE3 137.5
# 1
#                        fragment_name  fragment start (aa)  \
# 2606  gyrB1copies_1-804_gyrA_123-152                  123
#
#       fragment center (aa)  fragment end (aa)      iptm   plddt  n_contacts  \
# 2606                 137.5                152  0.188093  45.225          16
#
#                                                    path _merge  \
# 2606  /data1/groups/keatinglab/swans/savinovCollabor...   both
#
#       weighted_contacts  ... charge_Lehninger_classifier  \
# 2606           3.009485  ...                    negative
#
#      frag_contains_alphaHelix frag_contains_betaStrand  frag_contains_Turn  \
# 2606                      1.0                      1.0                 1.0
#
#       frag_centroid_fractional_position_classifier  \
# 2606                                    N-terminal
#
#                                             contact_set cluster cluster_size  \
# 2606  [(<Residue LEU het=  resseq=763 icode= >, <Res...      21            1
#
#      cluster first fragment center (aa)  cluster last fragment center (aa)
# 2606                              137.5                              137.5
#
# [1 rows x 28 columns]
# gyrA-coding-EcoliBL21DE3 147.5
# 0
# Empty DataFrame
# Columns: [fragment_name, fragment start (aa), fragment center (aa), fragment end (aa), iptm, plddt, n_contacts, path, _merge, weighted_contacts, gene, condition, fragment ID, fragment length (aa), E = inhibitory effect (enrichment), sem(E), hydrophobicity_KyteDoolittle_classifier, instabIndex_Guruprasad_classifier, charge_Lehninger_classifier, frag_contains_alphaHelix, frag_contains_betaStrand, frag_contains_Turn, frag_centroid_fractional_position_classifier, contact_set, cluster, cluster_size, cluster first fragment center (aa), cluster last fragment center (aa)]
# Index: []
#
# [0 rows x 28 columns]
# gyrA-coding-EcoliBL21DE3 183.5
# 0
# Empty DataFrame
# Columns: [fragment_name, fragment start (aa), fragment center (aa), fragment end (aa), iptm, plddt, n_contacts, path, _merge, weighted_contacts, gene, condition, fragment ID, fragment length (aa), E = inhibitory effect (enrichment), sem(E), hydrophobicity_KyteDoolittle_classifier, instabIndex_Guruprasad_classifier, charge_Lehninger_classifier, frag_contains_alphaHelix, frag_contains_betaStrand, frag_contains_Turn, frag_centroid_fractional_position_classifier, contact_set, cluster, cluster_size, cluster first fragment center (aa), cluster last fragment center (aa)]
# Index: []
#
# [0 rows x 28 columns]
# gyrA-coding-EcoliBL21DE3 270.5
# 0
# Empty DataFrame
# Columns: [fragment_name, fragment start (aa), fragment center (aa), fragment end (aa), iptm, plddt, n_contacts, path, _merge, weighted_contacts, gene, condition, fragment ID, fragment length (aa), E = inhibitory effect (enrichment), sem(E), hydrophobicity_KyteDoolittle_classifier, instabIndex_Guruprasad_classifier, charge_Lehninger_classifier, frag_contains_alphaHelix, frag_contains_betaStrand, frag_contains_Turn, frag_centroid_fractional_position_classifier, contact_set, cluster, cluster_size, cluster first fragment center (aa), cluster last fragment center (aa)]
# Index: []
#
# [0 rows x 28 columns]
# gyrA-coding-EcoliBL21DE3 340.5
# 0
# Empty DataFrame
# Columns: [fragment_name, fragment start (aa), fragment center (aa), fragment end (aa), iptm, plddt, n_contacts, path, _merge, weighted_contacts, gene, condition, fragment ID, fragment length (aa), E = inhibitory effect (enrichment), sem(E), hydrophobicity_KyteDoolittle_classifier, instabIndex_Guruprasad_classifier, charge_Lehninger_classifier, frag_contains_alphaHelix, frag_contains_betaStrand, frag_contains_Turn, frag_centroid_fractional_position_classifier, contact_set, cluster, cluster_size, cluster first fragment center (aa), cluster last fragment center (aa)]
# Index: []
#
# [0 rows x 28 columns]
# gyrA-coding-EcoliBL21DE3 375.5
# 0
# Empty DataFrame
# Columns: [fragment_name, fragment start (aa), fragment center (aa), fragment end (aa), iptm, plddt, n_contacts, path, _merge, weighted_contacts, gene, condition, fragment ID, fragment length (aa), E = inhibitory effect (enrichment), sem(E), hydrophobicity_KyteDoolittle_classifier, instabIndex_Guruprasad_classifier, charge_Lehninger_classifier, frag_contains_alphaHelix, frag_contains_betaStrand, frag_contains_Turn, frag_centroid_fractional_position_classifier, contact_set, cluster, cluster_size, cluster first fragment center (aa), cluster last fragment center (aa)]
# Index: []
#
# [0 rows x 28 columns]
# gyrA-coding-EcoliBL21DE3 489.5
# 0
# Empty DataFrame
# Columns: [fragment_name, fragment start (aa), fragment center (aa), fragment end (aa), iptm, plddt, n_contacts, path, _merge, weighted_contacts, gene, condition, fragment ID, fragment length (aa), E = inhibitory effect (enrichment), sem(E), hydrophobicity_KyteDoolittle_classifier, instabIndex_Guruprasad_classifier, charge_Lehninger_classifier, frag_contains_alphaHelix, frag_contains_betaStrand, frag_contains_Turn, frag_centroid_fractional_position_classifier, contact_set, cluster, cluster_size, cluster first fragment center (aa), cluster last fragment center (aa)]
# Index: []
#
# [0 rows x 28 columns]
# gyrA-coding-EcoliBL21DE3 492.5
# 0
# Empty DataFrame
# Columns: [fragment_name, fragment start (aa), fragment center (aa), fragment end (aa), iptm, plddt, n_contacts, path, _merge, weighted_contacts, gene, condition, fragment ID, fragment length (aa), E = inhibitory effect (enrichment), sem(E), hydrophobicity_KyteDoolittle_classifier, instabIndex_Guruprasad_classifier, charge_Lehninger_classifier, frag_contains_alphaHelix, frag_contains_betaStrand, frag_contains_Turn, frag_centroid_fractional_position_classifier, contact_set, cluster, cluster_size, cluster first fragment center (aa), cluster last fragment center (aa)]
# Index: []
#
# [0 rows x 28 columns]
# gyrA-coding-EcoliBL21DE3 669.5
# 0
# Empty DataFrame
# Columns: [fragment_name, fragment start (aa), fragment center (aa), fragment end (aa), iptm, plddt, n_contacts, path, _merge, weighted_contacts, gene, condition, fragment ID, fragment length (aa), E = inhibitory effect (enrichment), sem(E), hydrophobicity_KyteDoolittle_classifier, instabIndex_Guruprasad_classifier, charge_Lehninger_classifier, frag_contains_alphaHelix, frag_contains_betaStrand, frag_contains_Turn, frag_centroid_fractional_position_classifier, contact_set, cluster, cluster_size, cluster first fragment center (aa), cluster last fragment center (aa)]
# Index: []
#
# [0 rows x 28 columns]
# gyrA-coding-EcoliBL21DE3 783.5
# 0
# Empty DataFrame
# Columns: [fragment_name, fragment start (aa), fragment center (aa), fragment end (aa), iptm, plddt, n_contacts, path, _merge, weighted_contacts, gene, condition, fragment ID, fragment length (aa), E = inhibitory effect (enrichment), sem(E), hydrophobicity_KyteDoolittle_classifier, instabIndex_Guruprasad_classifier, charge_Lehninger_classifier, frag_contains_alphaHelix, frag_contains_betaStrand, frag_contains_Turn, frag_centroid_fractional_position_classifier, contact_set, cluster, cluster_size, cluster first fragment center (aa), cluster last fragment center (aa)]
# Index: []
#
# [0 rows x 28 columns]
# lptG-coding-EcoliBL21DE3 20.5
# 0
# Empty DataFrame
# Columns: [fragment_name, fragment start (aa), fragment center (aa), fragment end (aa), iptm, plddt, n_contacts, path, _merge, weighted_contacts, gene, condition, fragment ID, fragment length (aa), E = inhibitory effect (enrichment), sem(E), hydrophobicity_KyteDoolittle_classifier, instabIndex_Guruprasad_classifier, charge_Lehninger_classifier, frag_contains_alphaHelix, frag_contains_betaStrand, frag_contains_Turn, frag_centroid_fractional_position_classifier, contact_set, cluster, cluster_size, cluster first fragment center (aa), cluster last fragment center (aa)]
# Index: []
#
# [0 rows x 28 columns]
# lptG-coding-EcoliBL21DE3 76.5
# 0
# Empty DataFrame
# Columns: [fragment_name, fragment start (aa), fragment center (aa), fragment end (aa), iptm, plddt, n_contacts, path, _merge, weighted_contacts, gene, condition, fragment ID, fragment length (aa), E = inhibitory effect (enrichment), sem(E), hydrophobicity_KyteDoolittle_classifier, instabIndex_Guruprasad_classifier, charge_Lehninger_classifier, frag_contains_alphaHelix, frag_contains_betaStrand, frag_contains_Turn, frag_centroid_fractional_position_classifier, contact_set, cluster, cluster_size, cluster first fragment center (aa), cluster last fragment center (aa)]
# Index: []
#
# [0 rows x 28 columns]
# lptG-coding-EcoliBL21DE3 291.5
# 0
# Empty DataFrame
# Columns: [fragment_name, fragment start (aa), fragment center (aa), fragment end (aa), iptm, plddt, n_contacts, path, _merge, weighted_contacts, gene, condition, fragment ID, fragment length (aa), E = inhibitory effect (enrichment), sem(E), hydrophobicity_KyteDoolittle_classifier, instabIndex_Guruprasad_classifier, charge_Lehninger_classifier, frag_contains_alphaHelix, frag_contains_betaStrand, frag_contains_Turn, frag_centroid_fractional_position_classifier, contact_set, cluster, cluster_size, cluster first fragment center (aa), cluster last fragment center (aa)]
# Index: []
#
# [0 rows x 28 columns]
# ssb-coding-EcoliBL21DE3 94.5
# 0
# Empty DataFrame
# Columns: [fragment_name, fragment start (aa), fragment center (aa), fragment end (aa), iptm, plddt, n_contacts, path, _merge, weighted_contacts, gene, condition, fragment ID, fragment length (aa), E = inhibitory effect (enrichment), sem(E), hydrophobicity_KyteDoolittle_classifier, instabIndex_Guruprasad_classifier, charge_Lehninger_classifier, frag_contains_alphaHelix, frag_contains_betaStrand, frag_contains_Turn, frag_centroid_fractional_position_classifier, contact_set, cluster, cluster_size, cluster first fragment center (aa), cluster last fragment center (aa)]
# Index: []
#
# [0 rows x 28 columns]
# 26 experimental fragments with significant inhibition and 2 overlapping alphafold predictions

# %%
exp_filt_df[exp_filt_df['covered']==True][['gene','fragment center (aa)','covering']]
# Out:
#                         gene  fragment center (aa)  \
# 14  ftsZ-coding-EcoliBL21DE3                 213.5
# 24  gyrA-coding-EcoliBL21DE3                 137.5
#
#                             covering
# 14        [FtsZ_10-316_FtsZ_187-216]
# 24  [gyrB1copies_1-804_gyrA_123-152]

# %%
# relaxed definition
# experimental peak is covered if the center (fragment with max inhib effect)
# is within the range of the alphafold predictions + res_dist

res_dist = 15
exp_filt_df = exp_df[(exp_df['gene'].isin(benchmark_genes))&(exp_df['peak type']=='novel')].copy(deep=True)
pred_filt_df = pred_df[pred_df['condition'].isin(benchmark_conditions)]
print(f"{len(exp_filt_df)} experimental peaks and {len(pred_filt_df)} predicted")
count,covered = 0,0
covering_list = []
covered_list = []
for i,row in exp_filt_df.iterrows():
    print(row['gene'],row['fragment center (aa)'])
    frag_center_aa = row['fragment center (aa)']
    pred_covered = pred_df[(frag_center_aa+res_dist>=pred_df['cluster first fragment center (aa)'])&
                        (frag_center_aa-res_dist<=pred_df['cluster last fragment center (aa)'])&
                        (pred_df['gene']==row['gene'])]
    print(len(pred_covered))
    display(pred_covered.head(5))
    covering_list.append(list(pred_covered['fragment_name']))
    covered_list.append(True if len(pred_covered['fragment_name'])>0 else False)
    if len(pred_covered) > 0:
        covered += 1
    count += 1

exp_filt_df['covering'] = covering_list
exp_filt_df['covered'] = covered_list
print(f"{count} experimental fragments with significant inhibition and {covered} overlapping alphafold predictions")
# Out:
# 26 experimental peaks and 78 predicted
# folA-coding-EcoliBL21DE3 16.5
# 0
# Empty DataFrame
# Columns: [fragment_name, fragment start (aa), fragment center (aa), fragment end (aa), iptm, plddt, n_contacts, path, _merge, weighted_contacts, gene, condition, fragment ID, fragment length (aa), E = inhibitory effect (enrichment), sem(E), hydrophobicity_KyteDoolittle_classifier, instabIndex_Guruprasad_classifier, charge_Lehninger_classifier, frag_contains_alphaHelix, frag_contains_betaStrand, frag_contains_Turn, frag_centroid_fractional_position_classifier, contact_set, cluster, cluster_size, cluster first fragment center (aa), cluster last fragment center (aa)]
# Index: []
#
# [0 rows x 28 columns]
# folA-coding-EcoliBL21DE3 32.5
# 0
# Empty DataFrame
# Columns: [fragment_name, fragment start (aa), fragment center (aa), fragment end (aa), iptm, plddt, n_contacts, path, _merge, weighted_contacts, gene, condition, fragment ID, fragment length (aa), E = inhibitory effect (enrichment), sem(E), hydrophobicity_KyteDoolittle_classifier, instabIndex_Guruprasad_classifier, charge_Lehninger_classifier, frag_contains_alphaHelix, frag_contains_betaStrand, frag_contains_Turn, frag_centroid_fractional_position_classifier, contact_set, cluster, cluster_size, cluster first fragment center (aa), cluster last fragment center (aa)]
# Index: []
#
# [0 rows x 28 columns]
# folA-coding-EcoliBL21DE3 72.5
# 0
# Empty DataFrame
# Columns: [fragment_name, fragment start (aa), fragment center (aa), fragment end (aa), iptm, plddt, n_contacts, path, _merge, weighted_contacts, gene, condition, fragment ID, fragment length (aa), E = inhibitory effect (enrichment), sem(E), hydrophobicity_KyteDoolittle_classifier, instabIndex_Guruprasad_classifier, charge_Lehninger_classifier, frag_contains_alphaHelix, frag_contains_betaStrand, frag_contains_Turn, frag_centroid_fractional_position_classifier, contact_set, cluster, cluster_size, cluster first fragment center (aa), cluster last fragment center (aa)]
# Index: []
#
# [0 rows x 28 columns]
# folA-coding-EcoliBL21DE3 90.5
# 0
# Empty DataFrame
# Columns: [fragment_name, fragment start (aa), fragment center (aa), fragment end (aa), iptm, plddt, n_contacts, path, _merge, weighted_contacts, gene, condition, fragment ID, fragment length (aa), E = inhibitory effect (enrichment), sem(E), hydrophobicity_KyteDoolittle_classifier, instabIndex_Guruprasad_classifier, charge_Lehninger_classifier, frag_contains_alphaHelix, frag_contains_betaStrand, frag_contains_Turn, frag_centroid_fractional_position_classifier, contact_set, cluster, cluster_size, cluster first fragment center (aa), cluster last fragment center (aa)]
# Index: []
#
# [0 rows x 28 columns]
# folA-coding-EcoliBL21DE3 101.5
# 1
#              fragment_name  fragment start (aa)  fragment center (aa)  \
# 85  folA_1-159_folA_92-121                   92                 106.5
#
#     fragment end (aa)      iptm      plddt  n_contacts  \
# 85                121  0.487784  86.148333           7
#
#                                                  path _merge  \
# 85  /data1/groups/keatinglab/swans/savinovCollabor...   both
#
#     weighted_contacts  ... charge_Lehninger_classifier  \
# 85           3.414489  ...                     neutral
#
#    frag_contains_alphaHelix frag_contains_betaStrand  frag_contains_Turn  \
# 85                      1.0                      1.0                 0.0
#
#     frag_centroid_fractional_position_classifier  \
# 85                                    C-terminal
#
#                                           contact_set cluster cluster_size  \
# 85  [(<Residue PRO het=  resseq=130 icode= >, <Res...       2            1
#
#    cluster first fragment center (aa)  cluster last fragment center (aa)
# 85                              106.5                              106.5
#
# [1 rows x 28 columns]
# folA-coding-EcoliBL21DE3 125.5
# 0
# Empty DataFrame
# Columns: [fragment_name, fragment start (aa), fragment center (aa), fragment end (aa), iptm, plddt, n_contacts, path, _merge, weighted_contacts, gene, condition, fragment ID, fragment length (aa), E = inhibitory effect (enrichment), sem(E), hydrophobicity_KyteDoolittle_classifier, instabIndex_Guruprasad_classifier, charge_Lehninger_classifier, frag_contains_alphaHelix, frag_contains_betaStrand, frag_contains_Turn, frag_centroid_fractional_position_classifier, contact_set, cluster, cluster_size, cluster first fragment center (aa), cluster last fragment center (aa)]
# Index: []
#
# [0 rows x 28 columns]
# folA-coding-EcoliBL21DE3 142.5
# 0
# Empty DataFrame
# Columns: [fragment_name, fragment start (aa), fragment center (aa), fragment end (aa), iptm, plddt, n_contacts, path, _merge, weighted_contacts, gene, condition, fragment ID, fragment length (aa), E = inhibitory effect (enrichment), sem(E), hydrophobicity_KyteDoolittle_classifier, instabIndex_Guruprasad_classifier, charge_Lehninger_classifier, frag_contains_alphaHelix, frag_contains_betaStrand, frag_contains_Turn, frag_centroid_fractional_position_classifier, contact_set, cluster, cluster_size, cluster first fragment center (aa), cluster last fragment center (aa)]
# Index: []
#
# [0 rows x 28 columns]
# ftsZ-coding-EcoliBL21DE3 26.5
# 1
#              fragment_name  fragment start (aa)  fragment center (aa)  \
# 125  FtsZ_10-316_FtsZ_2-31                    2                  16.5
#
#      fragment end (aa)      iptm   plddt  n_contacts  \
# 125                 31  0.539908  82.679           6
#
#                                                   path _merge  \
# 125  /data1/groups/keatinglab/swans/savinovCollabor...   both
#
#      weighted_contacts  ... charge_Lehninger_classifier  \
# 125           3.239451  ...                    negative
#
#     frag_contains_alphaHelix frag_contains_betaStrand  frag_contains_Turn  \
# 125                      1.0                      1.0                 0.0
#
#      frag_centroid_fractional_position_classifier  \
# 125                                    N-terminal
#
#                                            contact_set cluster cluster_size  \
# 125  [(<Residue ARG het=  resseq=41 icode= >, <Resi...       7            1
#
#     cluster first fragment center (aa)  cluster last fragment center (aa)
# 125                               16.5                               16.5
#
# [1 rows x 28 columns]
# ftsZ-coding-EcoliBL21DE3 213.5
# 1
#                 fragment_name  fragment start (aa)  fragment center (aa)  \
# 310  FtsZ_10-316_FtsZ_187-216                  187                 201.5
#
#      fragment end (aa)      iptm      plddt  n_contacts  \
# 310                216  0.780989  85.832333          15
#
#                                                   path _merge  \
# 310  /data1/groups/keatinglab/swans/savinovCollabor...   both
#
#      weighted_contacts  ... charge_Lehninger_classifier  \
# 310          11.714832  ...                     neutral
#
#     frag_contains_alphaHelix frag_contains_betaStrand  frag_contains_Turn  \
# 310                      1.0                      0.0                 0.0
#
#      frag_centroid_fractional_position_classifier  \
# 310                                       central
#
#                                            contact_set cluster cluster_size  \
# 310  [(<Residue GLY het=  resseq=62 icode= >, <Resi...       4           28
#
#     cluster first fragment center (aa)  cluster last fragment center (aa)
# 310                              195.5                              222.5
#
# [1 rows x 28 columns]
# groL-coding-EcoliBL21DE3 175.5
# 0
# Empty DataFrame
# Columns: [fragment_name, fragment start (aa), fragment center (aa), fragment end (aa), iptm, plddt, n_contacts, path, _merge, weighted_contacts, gene, condition, fragment ID, fragment length (aa), E = inhibitory effect (enrichment), sem(E), hydrophobicity_KyteDoolittle_classifier, instabIndex_Guruprasad_classifier, charge_Lehninger_classifier, frag_contains_alphaHelix, frag_contains_betaStrand, frag_contains_Turn, frag_centroid_fractional_position_classifier, contact_set, cluster, cluster_size, cluster first fragment center (aa), cluster last fragment center (aa)]
# Index: []
#
# [0 rows x 28 columns]
# groL-coding-EcoliBL21DE3 185.5
# 0
# Empty DataFrame
# Columns: [fragment_name, fragment start (aa), fragment center (aa), fragment end (aa), iptm, plddt, n_contacts, path, _merge, weighted_contacts, gene, condition, fragment ID, fragment length (aa), E = inhibitory effect (enrichment), sem(E), hydrophobicity_KyteDoolittle_classifier, instabIndex_Guruprasad_classifier, charge_Lehninger_classifier, frag_contains_alphaHelix, frag_contains_betaStrand, frag_contains_Turn, frag_centroid_fractional_position_classifier, contact_set, cluster, cluster_size, cluster first fragment center (aa), cluster last fragment center (aa)]
# Index: []
#
# [0 rows x 28 columns]
# gyrA-coding-EcoliBL21DE3 89.5
# 4
#                       fragment_name  fragment start (aa)  \
# 1687          gyrA_1-872_gyrA_47-76                   47
# 1702          gyrA_1-872_gyrA_62-91                   62
# 2562  gyrB1copies_1-804_gyrA_79-108                   79
# 2565  gyrB1copies_1-804_gyrA_82-111                   82
#
#       fragment center (aa)  fragment end (aa)      iptm      plddt  \
# 1687                  61.5                 76  0.926111  88.088667
# 1702                  76.5                 91  0.965501  90.126333
# 2562                  93.5                108  0.345580  62.221333
# 2565                  96.5                111  0.528675  66.276667
#
#       n_contacts                                               path _merge  \
# 1687           5  /data1/groups/keatinglab/swans/savinovCollabor...   both
# 1702           8  /data1/groups/keatinglab/swans/savinovCollabor...   both
# 2562           9  /data1/groups/keatinglab/swans/savinovCollabor...   both
# 2565          10  /data1/groups/keatinglab/swans/savinovCollabor...   both
#
#       weighted_contacts  ... charge_Lehninger_classifier  \
# 1687           4.630556  ...                    positive
# 1702           7.724011  ...                    positive
# 2562           3.110217  ...                         NaN
# 2565           5.286747  ...                    negative
#
#      frag_contains_alphaHelix frag_contains_betaStrand  frag_contains_Turn  \
# 1687                      1.0                      1.0                 0.0
# 1702                      1.0                      0.0                 0.0
# 2562                      NaN                      NaN                 NaN
# 2565                      1.0                      1.0                 1.0
#
#       frag_centroid_fractional_position_classifier  \
# 1687                                    N-terminal
# 1702                                    N-terminal
# 2562                                           NaN
# 2565                                    N-terminal
#
#                                             contact_set cluster cluster_size  \
# 1687  [(<Residue ILE het=  resseq=74 icode= >, <Resi...       8            5
# 1702  [(<Residue ASP het=  resseq=82 icode= >, <Resi...       9           24
# 2562  [(<Residue GLU het=  resseq=793 icode= >, <Res...      24            1
# 2565  [(<Residue GLU het=  resseq=793 icode= >, <Res...      25            1
#
#      cluster first fragment center (aa)  cluster last fragment center (aa)
# 1687                               61.5                               81.5
# 1702                               58.5                               88.5
# 2562                               93.5                               93.5
# 2565                               96.5                               96.5
#
# [4 rows x 28 columns]
# gyrA-coding-EcoliBL21DE3 137.5
# 3
#                        fragment_name  fragment start (aa)  \
# 2602  gyrB1copies_1-804_gyrA_119-148                  119
# 2604  gyrB1copies_1-804_gyrA_121-150                  121
# 2606  gyrB1copies_1-804_gyrA_123-152                  123
#
#       fragment center (aa)  fragment end (aa)      iptm      plddt  \
# 2602                 133.5                148  0.274323  30.320000
# 2604                 135.5                150  0.230492  36.767667
# 2606                 137.5                152  0.188093  45.225000
#
#       n_contacts                                               path _merge  \
# 2602          13  /data1/groups/keatinglab/swans/savinovCollabor...   both
# 2604          19  /data1/groups/keatinglab/swans/savinovCollabor...   both
# 2606          16  /data1/groups/keatinglab/swans/savinovCollabor...   both
#
#       weighted_contacts  ... charge_Lehninger_classifier  \
# 2602           3.566198  ...                         NaN
# 2604           4.379348  ...                         NaN
# 2606           3.009485  ...                    negative
#
#      frag_contains_alphaHelix frag_contains_betaStrand  frag_contains_Turn  \
# 2602                      NaN                      NaN                 NaN
# 2604                      NaN                      NaN                 NaN
# 2606                      1.0                      1.0                 1.0
#
#       frag_centroid_fractional_position_classifier  \
# 2602                                           NaN
# 2604                                           NaN
# 2606                                    N-terminal
#
#                                             contact_set cluster cluster_size  \
# 2602  [(<Residue THR het=  resseq=508 icode= >, <Res...      20            1
# 2604  [(<Residue LEU het=  resseq=763 icode= >, <Res...      22            1
# 2606  [(<Residue LEU het=  resseq=763 icode= >, <Res...      21            1
#
#      cluster first fragment center (aa)  cluster last fragment center (aa)
# 2602                              133.5                              133.5
# 2604                              135.5                              135.5
# 2606                              137.5                              137.5
#
# [3 rows x 28 columns]
# gyrA-coding-EcoliBL21DE3 147.5
# 3
#                        fragment_name  fragment start (aa)  \
# 2602  gyrB1copies_1-804_gyrA_119-148                  119
# 2604  gyrB1copies_1-804_gyrA_121-150                  121
# 2606  gyrB1copies_1-804_gyrA_123-152                  123
#
#       fragment center (aa)  fragment end (aa)      iptm      plddt  \
# 2602                 133.5                148  0.274323  30.320000
# 2604                 135.5                150  0.230492  36.767667
# 2606                 137.5                152  0.188093  45.225000
#
#       n_contacts                                               path _merge  \
# 2602          13  /data1/groups/keatinglab/swans/savinovCollabor...   both
# 2604          19  /data1/groups/keatinglab/swans/savinovCollabor...   both
# 2606          16  /data1/groups/keatinglab/swans/savinovCollabor...   both
#
#       weighted_contacts  ... charge_Lehninger_classifier  \
# 2602           3.566198  ...                         NaN
# 2604           4.379348  ...                         NaN
# 2606           3.009485  ...                    negative
#
#      frag_contains_alphaHelix frag_contains_betaStrand  frag_contains_Turn  \
# 2602                      NaN                      NaN                 NaN
# 2604                      NaN                      NaN                 NaN
# 2606                      1.0                      1.0                 1.0
#
#       frag_centroid_fractional_position_classifier  \
# 2602                                           NaN
# 2604                                           NaN
# 2606                                    N-terminal
#
#                                             contact_set cluster cluster_size  \
# 2602  [(<Residue THR het=  resseq=508 icode= >, <Res...      20            1
# 2604  [(<Residue LEU het=  resseq=763 icode= >, <Res...      22            1
# 2606  [(<Residue LEU het=  resseq=763 icode= >, <Res...      21            1
#
#      cluster first fragment center (aa)  cluster last fragment center (aa)
# 2602                              133.5                              133.5
# 2604                              135.5                              135.5
# 2606                              137.5                              137.5
#
# [3 rows x 28 columns]
# gyrA-coding-EcoliBL21DE3 183.5
# 0
# Empty DataFrame
# Columns: [fragment_name, fragment start (aa), fragment center (aa), fragment end (aa), iptm, plddt, n_contacts, path, _merge, weighted_contacts, gene, condition, fragment ID, fragment length (aa), E = inhibitory effect (enrichment), sem(E), hydrophobicity_KyteDoolittle_classifier, instabIndex_Guruprasad_classifier, charge_Lehninger_classifier, frag_contains_alphaHelix, frag_contains_betaStrand, frag_contains_Turn, frag_centroid_fractional_position_classifier, contact_set, cluster, cluster_size, cluster first fragment center (aa), cluster last fragment center (aa)]
# Index: []
#
# [0 rows x 28 columns]
# gyrA-coding-EcoliBL21DE3 270.5
# 1
#                        fragment_name  fragment start (aa)  \
# 2731  gyrB1copies_1-804_gyrA_248-277                  248
#
#       fragment center (aa)  fragment end (aa)      iptm      plddt  \
# 2731                 262.5                277  0.331368  49.890667
#
#       n_contacts                                               path _merge  \
# 2731          21  /data1/groups/keatinglab/swans/savinovCollabor...   both
#
#       weighted_contacts  ... charge_Lehninger_classifier  \
# 2731            6.95873  ...                     neutral
#
#      frag_contains_alphaHelix frag_contains_betaStrand  frag_contains_Turn  \
# 2731                      1.0                      1.0                 0.0
#
#       frag_centroid_fractional_position_classifier  \
# 2731                                    N-terminal
#
#                                             contact_set cluster cluster_size  \
# 2731  [(<Residue GLU het=  resseq=793 icode= >, <Res...      27            1
#
#      cluster first fragment center (aa)  cluster last fragment center (aa)
# 2731                              262.5                              262.5
#
# [1 rows x 28 columns]
# gyrA-coding-EcoliBL21DE3 340.5
# 0
# Empty DataFrame
# Columns: [fragment_name, fragment start (aa), fragment center (aa), fragment end (aa), iptm, plddt, n_contacts, path, _merge, weighted_contacts, gene, condition, fragment ID, fragment length (aa), E = inhibitory effect (enrichment), sem(E), hydrophobicity_KyteDoolittle_classifier, instabIndex_Guruprasad_classifier, charge_Lehninger_classifier, frag_contains_alphaHelix, frag_contains_betaStrand, frag_contains_Turn, frag_centroid_fractional_position_classifier, contact_set, cluster, cluster_size, cluster first fragment center (aa), cluster last fragment center (aa)]
# Index: []
#
# [0 rows x 28 columns]
# gyrA-coding-EcoliBL21DE3 375.5
# 4
#                        fragment_name  fragment start (aa)  \
# 2019         gyrA_1-872_gyrA_379-408                  379
# 2849  gyrB1copies_1-804_gyrA_366-395                  366
# 2850  gyrB1copies_1-804_gyrA_367-396                  367
# 2851  gyrB1copies_1-804_gyrA_368-397                  368
#
#       fragment center (aa)  fragment end (aa)      iptm      plddt  \
# 2019                 393.5                408  0.902727  89.258000
# 2849                 380.5                395  0.387146  56.934000
# 2850                 381.5                396  0.410425  58.742333
# 2851                 382.5                397  0.397560  56.454667
#
#       n_contacts                                               path _merge  \
# 2019           7  /data1/groups/keatinglab/swans/savinovCollabor...   both
# 2849           8  /data1/groups/keatinglab/swans/savinovCollabor...   both
# 2850          11  /data1/groups/keatinglab/swans/savinovCollabor...   both
# 2851          11  /data1/groups/keatinglab/swans/savinovCollabor...   both
#
#       weighted_contacts  ... charge_Lehninger_classifier  \
# 2019           6.319088  ...                    negative
# 2849           3.097166  ...                     neutral
# 2850           4.514674  ...                     neutral
# 2851           4.373161  ...                     neutral
#
#      frag_contains_alphaHelix frag_contains_betaStrand  frag_contains_Turn  \
# 2019                      1.0                      1.0                 0.0
# 2849                      1.0                      0.0                 0.0
# 2850                      1.0                      0.0                 0.0
# 2851                      1.0                      0.0                 0.0
#
#       frag_centroid_fractional_position_classifier  \
# 2019                                       central
# 2849                                       central
# 2850                                       central
# 2851                                       central
#
#                                             contact_set cluster cluster_size  \
# 2019  [(<Residue THR het=  resseq=467 icode= >, <Res...       7           25
# 2849  [(<Residue SER het=  resseq=504 icode= >, <Res...      16            1
# 2850  [(<Residue ILE het=  resseq=804 icode= >, <Res...      29            1
# 2851  [(<Residue SER het=  resseq=504 icode= >, <Res...      17            1
#
#      cluster first fragment center (aa)  cluster last fragment center (aa)
# 2019                              388.5                              412.5
# 2849                              380.5                              380.5
# 2850                              381.5                              381.5
# 2851                              382.5                              382.5
#
# [4 rows x 28 columns]
# gyrA-coding-EcoliBL21DE3 489.5
# 1
#                 fragment_name  fragment start (aa)  fragment center (aa)  \
# 2081  gyrA_1-872_gyrA_441-470                  441                 455.5
#
#       fragment end (aa)      iptm   plddt  n_contacts  \
# 2081                470  0.920554  91.484          19
#
#                                                    path _merge  \
# 2081  /data1/groups/keatinglab/swans/savinovCollabor...   both
#
#       weighted_contacts  ... charge_Lehninger_classifier  \
# 2081          17.490527  ...                     neutral
#
#      frag_contains_alphaHelix frag_contains_betaStrand  frag_contains_Turn  \
# 2081                      1.0                      1.0                 0.0
#
#       frag_centroid_fractional_position_classifier  \
# 2081                                       central
#
#                                             contact_set cluster cluster_size  \
# 2081  [(<Residue GLN het=  resseq=464 icode= >, <Res...       6           33
#
#      cluster first fragment center (aa)  cluster last fragment center (aa)
# 2081                              445.5                              478.5
#
# [1 rows x 28 columns]
# gyrA-coding-EcoliBL21DE3 492.5
# 1
#                 fragment_name  fragment start (aa)  fragment center (aa)  \
# 2081  gyrA_1-872_gyrA_441-470                  441                 455.5
#
#       fragment end (aa)      iptm   plddt  n_contacts  \
# 2081                470  0.920554  91.484          19
#
#                                                    path _merge  \
# 2081  /data1/groups/keatinglab/swans/savinovCollabor...   both
#
#       weighted_contacts  ... charge_Lehninger_classifier  \
# 2081          17.490527  ...                     neutral
#
#      frag_contains_alphaHelix frag_contains_betaStrand  frag_contains_Turn  \
# 2081                      1.0                      1.0                 0.0
#
#       frag_centroid_fractional_position_classifier  \
# 2081                                       central
#
#                                             contact_set cluster cluster_size  \
# 2081  [(<Residue GLN het=  resseq=464 icode= >, <Res...       6           33
#
#      cluster first fragment center (aa)  cluster last fragment center (aa)
# 2081                              445.5                              478.5
#
# [1 rows x 28 columns]
# gyrA-coding-EcoliBL21DE3 669.5
# 0
# Empty DataFrame
# Columns: [fragment_name, fragment start (aa), fragment center (aa), fragment end (aa), iptm, plddt, n_contacts, path, _merge, weighted_contacts, gene, condition, fragment ID, fragment length (aa), E = inhibitory effect (enrichment), sem(E), hydrophobicity_KyteDoolittle_classifier, instabIndex_Guruprasad_classifier, charge_Lehninger_classifier, frag_contains_alphaHelix, frag_contains_betaStrand, frag_contains_Turn, frag_centroid_fractional_position_classifier, contact_set, cluster, cluster_size, cluster first fragment center (aa), cluster last fragment center (aa)]
# Index: []
#
# [0 rows x 28 columns]
# gyrA-coding-EcoliBL21DE3 783.5
# 1
#                        fragment_name  fragment start (aa)  \
# 3269  gyrB1copies_1-804_gyrA_786-815                  786
#
#       fragment center (aa)  fragment end (aa)      iptm      plddt  \
# 3269                 800.5                815  0.712247  76.003333
#
#       n_contacts                                               path _merge  \
# 3269          11  /data1/groups/keatinglab/swans/savinovCollabor...   both
#
#       weighted_contacts  ... charge_Lehninger_classifier  \
# 3269           7.834719  ...                    negative
#
#      frag_contains_alphaHelix frag_contains_betaStrand  frag_contains_Turn  \
# 3269                      1.0                      1.0                 0.0
#
#       frag_centroid_fractional_position_classifier  \
# 3269                                    C-terminal
#
#                                             contact_set cluster cluster_size  \
# 3269  [(<Residue ALA het=  resseq=796 icode= >, <Res...       1            9
#
#      cluster first fragment center (aa)  cluster last fragment center (aa)
# 3269                              793.5                              804.5
#
# [1 rows x 28 columns]
# lptG-coding-EcoliBL21DE3 20.5
# 5
#                      fragment_name  fragment start (aa)  fragment center (aa)  \
# 3691  lptF1copies_1-366_lptG_18-31                   18                  24.5
# 3692  lptF1copies_1-366_lptG_19-32                   19                  25.5
# 3693  lptF1copies_1-366_lptG_20-33                   20                  26.5
# 3697  lptF1copies_1-366_lptG_24-37                   24                  30.5
# 3702  lptF1copies_1-366_lptG_29-42                   29                  35.5
#
#       fragment end (aa)      iptm      plddt  n_contacts  \
# 3691                 31  0.593674  59.016333           9
# 3692                 32  0.556796  58.844667           7
# 3693                 33  0.583813  57.953000          10
# 3697                 37  0.843637  66.202333          10
# 3702                 42  0.741568  59.446333           6
#
#                                                    path _merge  \
# 3691  /data1/groups/keatinglab/swans/savinovCollabor...   both
# 3692  /data1/groups/keatinglab/swans/savinovCollabor...   both
# 3693  /data1/groups/keatinglab/swans/savinovCollabor...   both
# 3697  /data1/groups/keatinglab/swans/savinovCollabor...   both
# 3702  /data1/groups/keatinglab/swans/savinovCollabor...   both
#
#       weighted_contacts  ... charge_Lehninger_classifier  \
# 3691           5.343063  ...                     neutral
# 3692           3.897574  ...                     neutral
# 3693           5.838129  ...                     neutral
# 3697           8.436368  ...                     neutral
# 3702           4.449409  ...                    positive
#
#      frag_contains_alphaHelix frag_contains_betaStrand  frag_contains_Turn  \
# 3691                      1.0                      0.0                 0.0
# 3692                      1.0                      0.0                 0.0
# 3693                      1.0                      0.0                 0.0
# 3697                      1.0                      0.0                 0.0
# 3702                      1.0                      0.0                 0.0
#
#       frag_centroid_fractional_position_classifier  \
# 3691                                    N-terminal
# 3692                                    N-terminal
# 3693                                    N-terminal
# 3697                                    N-terminal
# 3702                                    N-terminal
#
#                                             contact_set cluster cluster_size  \
# 3691  [(<Residue ILE het=  resseq=25 icode= >, <Resi...      27            1
# 3692  [(<Residue PHE het=  resseq=26 icode= >, <Resi...      24            2
# 3693  [(<Residue LEU het=  resseq=62 icode= >, <Resi...      25            2
# 3697  [(<Residue LEU het=  resseq=62 icode= >, <Resi...      26            6
# 3702  [(<Residue ARG het=  resseq=33 icode= >, <Resi...      23            1
#
#      cluster first fragment center (aa)  cluster last fragment center (aa)
# 3691                               24.5                               24.5
# 3692                               23.5                               25.5
# 3693                               26.5                               27.5
# 3697                               28.5                               33.5
# 3702                               35.5                               35.5
#
# [5 rows x 28 columns]
# lptG-coding-EcoliBL21DE3 76.5
# 7
#                      fragment_name  fragment start (aa)  fragment center (aa)  \
# 3729  lptF1copies_1-366_lptG_56-69                   56                  62.5
# 3730  lptF1copies_1-366_lptG_57-70                   57                  63.5
# 3738  lptF1copies_1-366_lptG_65-78                   65                  71.5
# 3742  lptF1copies_1-366_lptG_69-82                   69                  75.5
# 3390         lptG_1-360_lptG_64-77                   64                  70.5
#
#       fragment end (aa)      iptm      plddt  n_contacts  \
# 3729                 69  0.656984  61.193000           7
# 3730                 70  0.705597  61.093667           5
# 3738                 78  0.589526  57.870000           6
# 3742                 82  0.645626  61.062333           5
# 3390                 77  0.628744  79.219000           8
#
#                                                    path _merge  \
# 3729  /data1/groups/keatinglab/swans/savinovCollabor...   both
# 3730  /data1/groups/keatinglab/swans/savinovCollabor...   both
# 3738  /data1/groups/keatinglab/swans/savinovCollabor...   both
# 3742  /data1/groups/keatinglab/swans/savinovCollabor...   both
# 3390  /data1/groups/keatinglab/swans/savinovCollabor...   both
#
#       weighted_contacts  ... charge_Lehninger_classifier  \
# 3729           4.598891  ...                     neutral
# 3730           3.527984  ...                     neutral
# 3738           3.537157  ...                     neutral
# 3742           3.228132  ...                     neutral
# 3390           5.029955  ...                     neutral
#
#      frag_contains_alphaHelix frag_contains_betaStrand  frag_contains_Turn  \
# 3729                      1.0                      0.0                 0.0
# 3730                      1.0                      0.0                 0.0
# 3738                      1.0                      0.0                 0.0
# 3742                      1.0                      0.0                 0.0
# 3390                      1.0                      0.0                 0.0
#
#       frag_centroid_fractional_position_classifier  \
# 3729                                    N-terminal
# 3730                                    N-terminal
# 3738                                    N-terminal
# 3742                                    N-terminal
# 3390                                    N-terminal
#
#                                             contact_set cluster cluster_size  \
# 3729  [(<Residue SER het=  resseq=315 icode= >, <Res...      28            2
# 3730  [(<Residue LEU het=  resseq=311 icode= >, <Res...      29            1
# 3738  [(<Residue ILE het=  resseq=25 icode= >, <Resi...      30            1
# 3742  [(<Residue ILE het=  resseq=25 icode= >, <Resi...      31            1
# 3390  [(<Residue MET het=  resseq=25 icode= >, <Resi...       4            1
#
#      cluster first fragment center (aa)  cluster last fragment center (aa)
# 3729                               60.5                               62.5
# 3730                               63.5                               63.5
# 3738                               71.5                               71.5
# 3742                               75.5                               75.5
# 3390                               70.5                               70.5
#
# [5 rows x 28 columns]
# lptG-coding-EcoliBL21DE3 291.5
# 2
#                        fragment_name  fragment start (aa)  \
# 3953  lptF1copies_1-366_lptG_280-293                  280
# 3973  lptF1copies_1-366_lptG_300-313                  300
#
#       fragment center (aa)  fragment end (aa)      iptm      plddt  \
# 3953                 286.5                293  0.651740  60.948667
# 3973                 306.5                313  0.454267  57.564667
#
#       n_contacts                                               path _merge  \
# 3953           9  /data1/groups/keatinglab/swans/savinovCollabor...   both
# 3973           8  /data1/groups/keatinglab/swans/savinovCollabor...   both
#
#       weighted_contacts  ... charge_Lehninger_classifier  \
# 3953           5.865663  ...                     neutral
# 3973           3.634135  ...                    positive
#
#      frag_contains_alphaHelix frag_contains_betaStrand  frag_contains_Turn  \
# 3953                      1.0                      0.0                 0.0
# 3973                      1.0                      0.0                 0.0
#
#       frag_centroid_fractional_position_classifier  \
# 3953                                    C-terminal
# 3973                                    C-terminal
#
#                                             contact_set cluster cluster_size  \
# 3953  [(<Residue LEU het=  resseq=311 icode= >, <Res...      36            1
# 3973  [(<Residue LEU het=  resseq=305 icode= >, <Res...      37            1
#
#      cluster first fragment center (aa)  cluster last fragment center (aa)
# 3953                              286.5                              286.5
# 3973                              306.5                              306.5
#
# [2 rows x 28 columns]
# ssb-coding-EcoliBL21DE3 94.5
# 25
#                     fragment_name  fragment start (aa)  fragment center (aa)  \
# 4407  ssb2copies_1-178_ssb_85-114                   85                  99.5
# 4286         ssb_1-178_ssb_83-112                   83                  97.5
# 4536   ssb4copies_1-178_ssb_65-94                   65                  79.5
# 4539   ssb4copies_1-178_ssb_68-97                   68                  82.5
# 4541   ssb4copies_1-178_ssb_70-99                   70                  84.5
#
#       fragment end (aa)      iptm      plddt  n_contacts  \
# 4407                114  0.607407  78.426333           5
# 4286                112  0.776913  89.987667           4
# 4536                 94  0.676761  65.887000           5
# 4539                 97  0.677151  66.274000           6
# 4541                 99  0.676943  63.818333           6
#
#                                                    path _merge  \
# 4407  /data1/groups/keatinglab/swans/savinovCollabor...   both
# 4286  /data1/groups/keatinglab/swans/savinovCollabor...   both
# 4536  /data1/groups/keatinglab/swans/savinovCollabor...   both
# 4539  /data1/groups/keatinglab/swans/savinovCollabor...   both
# 4541  /data1/groups/keatinglab/swans/savinovCollabor...   both
#
#       weighted_contacts  ... charge_Lehninger_classifier  \
# 4407           3.037035  ...                     neutral
# 4286           3.107653  ...                     neutral
# 4536           3.383807  ...                    positive
# 4539           4.062907  ...                    positive
# 4541           4.061655  ...                    positive
#
#      frag_contains_alphaHelix frag_contains_betaStrand  frag_contains_Turn  \
# 4407                      0.0                      1.0                 0.0
# 4286                      0.0                      1.0                 0.0
# 4536                      1.0                      1.0                 0.0
# 4539                      1.0                      1.0                 0.0
# 4541                      1.0                      1.0                 0.0
#
#       frag_centroid_fractional_position_classifier  \
# 4407                                       central
# 4286                                       central
# 4536                                       central
# 4539                                       central
# 4541                                       central
#
#                                             contact_set cluster cluster_size  \
# 4407  [(<Residue ARG het=  resseq=85 icode= >, <Resi...       8            1
# 4286  [(<Residue GLU het=  resseq=54 icode= >, <Resi...       1            2
# 4536  [(<Residue ILE het=  resseq=12 icode= >, <Resi...      19            1
# 4539  [(<Residue LYS het=  resseq=8 icode= >, <Resid...      21            1
# 4541  [(<Residue ILE het=  resseq=12 icode= >, <Resi...      16            1
#
#      cluster first fragment center (aa)  cluster last fragment center (aa)
# 4407                               99.5                               99.5
# 4286                               95.5                               97.5
# 4536                               79.5                               79.5
# 4539                               82.5                               82.5
# 4541                               84.5                               84.5
#
# [5 rows x 28 columns]
# 26 experimental fragments with significant inhibition and 15 overlapping alphafold predictions

# %%
exp_filt_df[exp_filt_df['covered']==True][['gene','fragment center (aa)','covering']]
# Out:
#                         gene  fragment center (aa)  \
# 7   folA-coding-EcoliBL21DE3                 101.5
# 10  ftsZ-coding-EcoliBL21DE3                  26.5
# 14  ftsZ-coding-EcoliBL21DE3                 213.5
# 23  gyrA-coding-EcoliBL21DE3                  89.5
# 24  gyrA-coding-EcoliBL21DE3                 137.5
# 25  gyrA-coding-EcoliBL21DE3                 147.5
# 27  gyrA-coding-EcoliBL21DE3                 270.5
# 29  gyrA-coding-EcoliBL21DE3                 375.5
# 31  gyrA-coding-EcoliBL21DE3                 489.5
# 32  gyrA-coding-EcoliBL21DE3                 492.5
# 34  gyrA-coding-EcoliBL21DE3                 783.5
# 60  lptG-coding-EcoliBL21DE3                  20.5
# 61  lptG-coding-EcoliBL21DE3                  76.5
# 62  lptG-coding-EcoliBL21DE3                 291.5
# 94   ssb-coding-EcoliBL21DE3                  94.5
#
#                                              covering
# 7                            [folA_1-159_folA_92-121]
# 10                            [FtsZ_10-316_FtsZ_2-31]
# 14                         [FtsZ_10-316_FtsZ_187-216]
# 23  [gyrA_1-872_gyrA_47-76, gyrA_1-872_gyrA_62-91,...
# 24  [gyrB1copies_1-804_gyrA_119-148, gyrB1copies_1...
# 25  [gyrB1copies_1-804_gyrA_119-148, gyrB1copies_1...
# 27                   [gyrB1copies_1-804_gyrA_248-277]
# 29  [gyrA_1-872_gyrA_379-408, gyrB1copies_1-804_gy...
# 31                          [gyrA_1-872_gyrA_441-470]
# 32                          [gyrA_1-872_gyrA_441-470]
# 34                   [gyrB1copies_1-804_gyrA_786-815]
# 60  [lptF1copies_1-366_lptG_18-31, lptF1copies_1-3...
# 61  [lptF1copies_1-366_lptG_56-69, lptF1copies_1-3...
# 62  [lptF1copies_1-366_lptG_280-293, lptF1copies_1...
# 94  [ssb2copies_1-178_ssb_85-114, ssb_1-178_ssb_83...

# %%
def range_overlap(startA,endA,startB,endB):
    # check if there is no overlap, then negate
    return not ((endA < startB) or (endB < startA))

print(range_overlap(0,10,10,20))
print(range_overlap(0,10,11,20))
print(range_overlap(10,20,1,20))
print(range_overlap(10,20,1,2))
# Out:
# True
# False
# True
# False

# %%
# relaxed definition 2
# experimental peak is covered if the range overlaps with
# the range of the alphafold predictions 

# res_dist = 15
exp_filt_df = exp_df[(exp_df['gene'].isin(benchmark_genes))].copy(deep=True)
# exp_filt_df = exp_df[(exp_df['gene'].isin(benchmark_genes))&(exp_df['peak type']=='novel')].copy(deep=True)
pred_filt_df = pred_df[pred_df['condition'].isin(benchmark_conditions)]
print(f"{len(exp_filt_df)} experimental peaks and {len(pred_filt_df)} predicted")
count,covered = 0,0
covering_list = []
covered_list = []
for i,row in exp_filt_df.iterrows():
    print(row['gene'],row['fragment center (aa)'])
    frag_center_aa = row['fragment center (aa)']
    frag_center_aa_first = row['peak region first fragment center (aa)']
    frag_center_aa_last = row['peak region last fragment center (aa)']
    
    # slightly confusing: condition is true if there is overlap
    # achieve this by checking if there is NOT overlap and then negating that
    pred_covered = pred_df[(pred_df['gene']==row['gene'])&
                           ~((frag_center_aa_first > pred_df['cluster last fragment center (aa)'])|
                             (frag_center_aa_last  < pred_df['cluster first fragment center (aa)']))
                          ]
    print(len(pred_covered))
    display(pred_covered.head(5))
    covering_list.append(list(pred_covered['fragment_name']))
    covered_list.append(True if len(pred_covered['fragment_name'])>0 else False)
    if len(pred_covered) > 0:
        covered += 1
    count += 1

exp_filt_df['covering'] = covering_list
exp_filt_df['covered'] = covered_list
print(f"{count} experimental fragments with significant inhibition and {covered} overlapping alphafold predictions")
# Out:
# 39 experimental peaks and 78 predicted
# folA-coding-EcoliBL21DE3 16.5
# 0
# Empty DataFrame
# Columns: [fragment_name, fragment start (aa), fragment center (aa), fragment end (aa), iptm, plddt, n_contacts, path, _merge, weighted_contacts, gene, condition, fragment ID, fragment length (aa), E = inhibitory effect (enrichment), sem(E), hydrophobicity_KyteDoolittle_classifier, instabIndex_Guruprasad_classifier, charge_Lehninger_classifier, frag_contains_alphaHelix, frag_contains_betaStrand, frag_contains_Turn, frag_centroid_fractional_position_classifier, contact_set, cluster, cluster_size, cluster first fragment center (aa), cluster last fragment center (aa)]
# Index: []
#
# [0 rows x 28 columns]
# folA-coding-EcoliBL21DE3 32.5
# 0
# Empty DataFrame
# Columns: [fragment_name, fragment start (aa), fragment center (aa), fragment end (aa), iptm, plddt, n_contacts, path, _merge, weighted_contacts, gene, condition, fragment ID, fragment length (aa), E = inhibitory effect (enrichment), sem(E), hydrophobicity_KyteDoolittle_classifier, instabIndex_Guruprasad_classifier, charge_Lehninger_classifier, frag_contains_alphaHelix, frag_contains_betaStrand, frag_contains_Turn, frag_centroid_fractional_position_classifier, contact_set, cluster, cluster_size, cluster first fragment center (aa), cluster last fragment center (aa)]
# Index: []
#
# [0 rows x 28 columns]
# folA-coding-EcoliBL21DE3 72.5
# 0
# Empty DataFrame
# Columns: [fragment_name, fragment start (aa), fragment center (aa), fragment end (aa), iptm, plddt, n_contacts, path, _merge, weighted_contacts, gene, condition, fragment ID, fragment length (aa), E = inhibitory effect (enrichment), sem(E), hydrophobicity_KyteDoolittle_classifier, instabIndex_Guruprasad_classifier, charge_Lehninger_classifier, frag_contains_alphaHelix, frag_contains_betaStrand, frag_contains_Turn, frag_centroid_fractional_position_classifier, contact_set, cluster, cluster_size, cluster first fragment center (aa), cluster last fragment center (aa)]
# Index: []
#
# [0 rows x 28 columns]
# folA-coding-EcoliBL21DE3 90.5
# 0
# Empty DataFrame
# Columns: [fragment_name, fragment start (aa), fragment center (aa), fragment end (aa), iptm, plddt, n_contacts, path, _merge, weighted_contacts, gene, condition, fragment ID, fragment length (aa), E = inhibitory effect (enrichment), sem(E), hydrophobicity_KyteDoolittle_classifier, instabIndex_Guruprasad_classifier, charge_Lehninger_classifier, frag_contains_alphaHelix, frag_contains_betaStrand, frag_contains_Turn, frag_centroid_fractional_position_classifier, contact_set, cluster, cluster_size, cluster first fragment center (aa), cluster last fragment center (aa)]
# Index: []
#
# [0 rows x 28 columns]
# folA-coding-EcoliBL21DE3 101.5
# 0
# Empty DataFrame
# Columns: [fragment_name, fragment start (aa), fragment center (aa), fragment end (aa), iptm, plddt, n_contacts, path, _merge, weighted_contacts, gene, condition, fragment ID, fragment length (aa), E = inhibitory effect (enrichment), sem(E), hydrophobicity_KyteDoolittle_classifier, instabIndex_Guruprasad_classifier, charge_Lehninger_classifier, frag_contains_alphaHelix, frag_contains_betaStrand, frag_contains_Turn, frag_centroid_fractional_position_classifier, contact_set, cluster, cluster_size, cluster first fragment center (aa), cluster last fragment center (aa)]
# Index: []
#
# [0 rows x 28 columns]
# folA-coding-EcoliBL21DE3 125.5
# 0
# Empty DataFrame
# Columns: [fragment_name, fragment start (aa), fragment center (aa), fragment end (aa), iptm, plddt, n_contacts, path, _merge, weighted_contacts, gene, condition, fragment ID, fragment length (aa), E = inhibitory effect (enrichment), sem(E), hydrophobicity_KyteDoolittle_classifier, instabIndex_Guruprasad_classifier, charge_Lehninger_classifier, frag_contains_alphaHelix, frag_contains_betaStrand, frag_contains_Turn, frag_centroid_fractional_position_classifier, contact_set, cluster, cluster_size, cluster first fragment center (aa), cluster last fragment center (aa)]
# Index: []
#
# [0 rows x 28 columns]
# folA-coding-EcoliBL21DE3 142.5
# 0
# Empty DataFrame
# Columns: [fragment_name, fragment start (aa), fragment center (aa), fragment end (aa), iptm, plddt, n_contacts, path, _merge, weighted_contacts, gene, condition, fragment ID, fragment length (aa), E = inhibitory effect (enrichment), sem(E), hydrophobicity_KyteDoolittle_classifier, instabIndex_Guruprasad_classifier, charge_Lehninger_classifier, frag_contains_alphaHelix, frag_contains_betaStrand, frag_contains_Turn, frag_centroid_fractional_position_classifier, contact_set, cluster, cluster_size, cluster first fragment center (aa), cluster last fragment center (aa)]
# Index: []
#
# [0 rows x 28 columns]
# ftsZ-coding-EcoliBL21DE3 26.5
# 0
# Empty DataFrame
# Columns: [fragment_name, fragment start (aa), fragment center (aa), fragment end (aa), iptm, plddt, n_contacts, path, _merge, weighted_contacts, gene, condition, fragment ID, fragment length (aa), E = inhibitory effect (enrichment), sem(E), hydrophobicity_KyteDoolittle_classifier, instabIndex_Guruprasad_classifier, charge_Lehninger_classifier, frag_contains_alphaHelix, frag_contains_betaStrand, frag_contains_Turn, frag_centroid_fractional_position_classifier, contact_set, cluster, cluster_size, cluster first fragment center (aa), cluster last fragment center (aa)]
# Index: []
#
# [0 rows x 28 columns]
# ftsZ-coding-EcoliBL21DE3 130.5
# 0
# Empty DataFrame
# Columns: [fragment_name, fragment start (aa), fragment center (aa), fragment end (aa), iptm, plddt, n_contacts, path, _merge, weighted_contacts, gene, condition, fragment ID, fragment length (aa), E = inhibitory effect (enrichment), sem(E), hydrophobicity_KyteDoolittle_classifier, instabIndex_Guruprasad_classifier, charge_Lehninger_classifier, frag_contains_alphaHelix, frag_contains_betaStrand, frag_contains_Turn, frag_centroid_fractional_position_classifier, contact_set, cluster, cluster_size, cluster first fragment center (aa), cluster last fragment center (aa)]
# Index: []
#
# [0 rows x 28 columns]
# ftsZ-coding-EcoliBL21DE3 174.5
# 1
#                 fragment_name  fragment start (aa)  fragment center (aa)  \
# 289  FtsZ_10-316_FtsZ_166-195                  166                 180.5
#
#      fragment end (aa)      iptm      plddt  n_contacts  \
# 289                195  0.802524  88.135333           9
#
#                                                   path _merge  \
# 289  /data1/groups/keatinglab/swans/savinovCollabor...   both
#
#      weighted_contacts  ... charge_Lehninger_classifier  \
# 289           7.222718  ...                     neutral
#
#     frag_contains_alphaHelix frag_contains_betaStrand  frag_contains_Turn  \
# 289                      1.0                      0.0                 0.0
#
#      frag_centroid_fractional_position_classifier  \
# 289                                       central
#
#                                            contact_set cluster cluster_size  \
# 289  [(<Residue LEU het=  resseq=263 icode= >, <Res...       5           22
#
#     cluster first fragment center (aa)  cluster last fragment center (aa)
# 289                              164.5                              186.5
#
# [1 rows x 28 columns]
# ftsZ-coding-EcoliBL21DE3 190.5
# 1
#                 fragment_name  fragment start (aa)  fragment center (aa)  \
# 310  FtsZ_10-316_FtsZ_187-216                  187                 201.5
#
#      fragment end (aa)      iptm      plddt  n_contacts  \
# 310                216  0.780989  85.832333          15
#
#                                                   path _merge  \
# 310  /data1/groups/keatinglab/swans/savinovCollabor...   both
#
#      weighted_contacts  ... charge_Lehninger_classifier  \
# 310          11.714832  ...                     neutral
#
#     frag_contains_alphaHelix frag_contains_betaStrand  frag_contains_Turn  \
# 310                      1.0                      0.0                 0.0
#
#      frag_centroid_fractional_position_classifier  \
# 310                                       central
#
#                                            contact_set cluster cluster_size  \
# 310  [(<Residue GLY het=  resseq=62 icode= >, <Resi...       4           28
#
#     cluster first fragment center (aa)  cluster last fragment center (aa)
# 310                              195.5                              222.5
#
# [1 rows x 28 columns]
# ftsZ-coding-EcoliBL21DE3 213.5
# 1
#                 fragment_name  fragment start (aa)  fragment center (aa)  \
# 310  FtsZ_10-316_FtsZ_187-216                  187                 201.5
#
#      fragment end (aa)      iptm      plddt  n_contacts  \
# 310                216  0.780989  85.832333          15
#
#                                                   path _merge  \
# 310  /data1/groups/keatinglab/swans/savinovCollabor...   both
#
#      weighted_contacts  ... charge_Lehninger_classifier  \
# 310          11.714832  ...                     neutral
#
#     frag_contains_alphaHelix frag_contains_betaStrand  frag_contains_Turn  \
# 310                      1.0                      0.0                 0.0
#
#      frag_centroid_fractional_position_classifier  \
# 310                                       central
#
#                                            contact_set cluster cluster_size  \
# 310  [(<Residue GLY het=  resseq=62 icode= >, <Resi...       4           28
#
#     cluster first fragment center (aa)  cluster last fragment center (aa)
# 310                              195.5                              222.5
#
# [1 rows x 28 columns]
# ftsZ-coding-EcoliBL21DE3 272.5
# 1
#                 fragment_name  fragment start (aa)  fragment center (aa)  \
# 389  FtsZ_10-316_FtsZ_266-295                  266                 280.5
#
#      fragment end (aa)      iptm      plddt  n_contacts  \
# 389                295  0.753369  81.148667          12
#
#                                                   path _merge  \
# 389  /data1/groups/keatinglab/swans/savinovCollabor...   both
#
#      weighted_contacts  ... charge_Lehninger_classifier  \
# 389           9.040423  ...                    negative
#
#     frag_contains_alphaHelix frag_contains_betaStrand  frag_contains_Turn  \
# 389                      1.0                      1.0                 0.0
#
#      frag_centroid_fractional_position_classifier  \
# 389                                    C-terminal
#
#                                            contact_set cluster cluster_size  \
# 389  [(<Residue ARG het=  resseq=133 icode= >, <Res...       1           29
#
#     cluster first fragment center (aa)  cluster last fragment center (aa)
# 389                              257.5                              285.5
#
# [1 rows x 28 columns]
# ftsZ-coding-EcoliBL21DE3 367.5
# 1
#                 fragment_name  fragment start (aa)  fragment center (aa)  \
# 475  FtsZ_10-316_FtsZ_352-381                  352                 366.5
#
#      fragment end (aa)      iptm      plddt  n_contacts  \
# 475                381  0.273637  46.714667          12
#
#                                                   path _merge  \
# 475  /data1/groups/keatinglab/swans/savinovCollabor...   both
#
#      weighted_contacts  ... charge_Lehninger_classifier  \
# 475           3.283643  ...                     neutral
#
#     frag_contains_alphaHelix frag_contains_betaStrand  frag_contains_Turn  \
# 475                      1.0                      0.0                 0.0
#
#      frag_centroid_fractional_position_classifier  \
# 475                                    C-terminal
#
#                                            contact_set cluster cluster_size  \
# 475  [(<Residue ARG het=  resseq=22 icode= >, <Resi...       8            1
#
#     cluster first fragment center (aa)  cluster last fragment center (aa)
# 475                              366.5                              366.5
#
# [1 rows x 28 columns]
# groL-coding-EcoliBL21DE3 17.5
# 1
#               fragment_name  fragment start (aa)  fragment center (aa)  \
# 477  groEL_1-548_groEL_1-30                    1                  15.5
#
#      fragment end (aa)      iptm      plddt  n_contacts  \
# 477                 30  0.882917  89.506333           5
#
#                                                   path _merge  \
# 477  /data1/groups/keatinglab/swans/savinovCollabor...   both
#
#      weighted_contacts  ... charge_Lehninger_classifier  \
# 477           4.414584  ...                    positive
#
#     frag_contains_alphaHelix frag_contains_betaStrand  frag_contains_Turn  \
# 477                      1.0                      1.0                 0.0
#
#      frag_centroid_fractional_position_classifier  \
# 477                                    N-terminal
#
#                                            contact_set cluster cluster_size  \
# 477  [(<Residue GLU het=  resseq=63 icode= >, <Resi...       5            2
#
#     cluster first fragment center (aa)  cluster last fragment center (aa)
# 477                               15.5                               17.5
#
# [1 rows x 28 columns]
# groL-coding-EcoliBL21DE3 175.5
# 0
# Empty DataFrame
# Columns: [fragment_name, fragment start (aa), fragment center (aa), fragment end (aa), iptm, plddt, n_contacts, path, _merge, weighted_contacts, gene, condition, fragment ID, fragment length (aa), E = inhibitory effect (enrichment), sem(E), hydrophobicity_KyteDoolittle_classifier, instabIndex_Guruprasad_classifier, charge_Lehninger_classifier, frag_contains_alphaHelix, frag_contains_betaStrand, frag_contains_Turn, frag_centroid_fractional_position_classifier, contact_set, cluster, cluster_size, cluster first fragment center (aa), cluster last fragment center (aa)]
# Index: []
#
# [0 rows x 28 columns]
# groL-coding-EcoliBL21DE3 185.5
# 0
# Empty DataFrame
# Columns: [fragment_name, fragment start (aa), fragment center (aa), fragment end (aa), iptm, plddt, n_contacts, path, _merge, weighted_contacts, gene, condition, fragment ID, fragment length (aa), E = inhibitory effect (enrichment), sem(E), hydrophobicity_KyteDoolittle_classifier, instabIndex_Guruprasad_classifier, charge_Lehninger_classifier, frag_contains_alphaHelix, frag_contains_betaStrand, frag_contains_Turn, frag_centroid_fractional_position_classifier, contact_set, cluster, cluster_size, cluster first fragment center (aa), cluster last fragment center (aa)]
# Index: []
#
# [0 rows x 28 columns]
# groL-coding-EcoliBL21DE3 243.5
# 0
# Empty DataFrame
# Columns: [fragment_name, fragment start (aa), fragment center (aa), fragment end (aa), iptm, plddt, n_contacts, path, _merge, weighted_contacts, gene, condition, fragment ID, fragment length (aa), E = inhibitory effect (enrichment), sem(E), hydrophobicity_KyteDoolittle_classifier, instabIndex_Guruprasad_classifier, charge_Lehninger_classifier, frag_contains_alphaHelix, frag_contains_betaStrand, frag_contains_Turn, frag_centroid_fractional_position_classifier, contact_set, cluster, cluster_size, cluster first fragment center (aa), cluster last fragment center (aa)]
# Index: []
#
# [0 rows x 28 columns]
# groL-coding-EcoliBL21DE3 260.5
# 1
#                         fragment_name  fragment start (aa)  \
# 1371  groES1copies_1-97_groEL_250-279                  250
#
#       fragment center (aa)  fragment end (aa)      iptm      plddt  \
# 1371                 264.5                279  0.659761  88.393667
#
#       n_contacts                                               path _merge  \
# 1371           8  /data1/groups/keatinglab/swans/savinovCollabor...   both
#
#       weighted_contacts  ... charge_Lehninger_classifier  \
# 1371           5.278087  ...                     neutral
#
#      frag_contains_alphaHelix frag_contains_betaStrand  frag_contains_Turn  \
# 1371                      1.0                      1.0                 0.0
#
#       frag_centroid_fractional_position_classifier  \
# 1371                                       central
#
#                                             contact_set cluster cluster_size  \
# 1371  [(<Residue VAL het=  resseq=26 icode= >, <Resi...       1            7
#
#      cluster first fragment center (aa)  cluster last fragment center (aa)
# 1371                              257.5                              272.5
#
# [1 rows x 28 columns]
# gyrA-coding-EcoliBL21DE3 26.5
# 1
#                     fragment_name  fragment start (aa)  fragment center (aa)  \
# 2485  gyrB1copies_1-804_gyrA_2-31                    2                  16.5
#
#       fragment end (aa)      iptm      plddt  n_contacts  \
# 2485                 31  0.939134  83.196333          36
#
#                                                    path _merge  \
# 2485  /data1/groups/keatinglab/swans/savinovCollabor...   both
#
#       weighted_contacts  ... charge_Lehninger_classifier  \
# 2485          33.808818  ...                    negative
#
#      frag_contains_alphaHelix frag_contains_betaStrand  frag_contains_Turn  \
# 2485                      0.0                      0.0                 1.0
#
#       frag_centroid_fractional_position_classifier  \
# 2485                                    N-terminal
#
#                                             contact_set cluster cluster_size  \
# 2485  [(<Residue ILE het=  resseq=802 icode= >, <Res...      23           20
#
#      cluster first fragment center (aa)  cluster last fragment center (aa)
# 2485                               15.5                               34.5
#
# [1 rows x 28 columns]
# gyrA-coding-EcoliBL21DE3 89.5
# 3
#                       fragment_name  fragment start (aa)  \
# 1702          gyrA_1-872_gyrA_62-91                   62
# 2562  gyrB1copies_1-804_gyrA_79-108                   79
# 2565  gyrB1copies_1-804_gyrA_82-111                   82
#
#       fragment center (aa)  fragment end (aa)      iptm      plddt  \
# 1702                  76.5                 91  0.965501  90.126333
# 2562                  93.5                108  0.345580  62.221333
# 2565                  96.5                111  0.528675  66.276667
#
#       n_contacts                                               path _merge  \
# 1702           8  /data1/groups/keatinglab/swans/savinovCollabor...   both
# 2562           9  /data1/groups/keatinglab/swans/savinovCollabor...   both
# 2565          10  /data1/groups/keatinglab/swans/savinovCollabor...   both
#
#       weighted_contacts  ... charge_Lehninger_classifier  \
# 1702           7.724011  ...                    positive
# 2562           3.110217  ...                         NaN
# 2565           5.286747  ...                    negative
#
#      frag_contains_alphaHelix frag_contains_betaStrand  frag_contains_Turn  \
# 1702                      1.0                      0.0                 0.0
# 2562                      NaN                      NaN                 NaN
# 2565                      1.0                      1.0                 1.0
#
#       frag_centroid_fractional_position_classifier  \
# 1702                                    N-terminal
# 2562                                           NaN
# 2565                                    N-terminal
#
#                                             contact_set cluster cluster_size  \
# 1702  [(<Residue ASP het=  resseq=82 icode= >, <Resi...       9           24
# 2562  [(<Residue GLU het=  resseq=793 icode= >, <Res...      24            1
# 2565  [(<Residue GLU het=  resseq=793 icode= >, <Res...      25            1
#
#      cluster first fragment center (aa)  cluster last fragment center (aa)
# 1702                               58.5                               88.5
# 2562                               93.5                               93.5
# 2565                               96.5                               96.5
#
# [3 rows x 28 columns]
# gyrA-coding-EcoliBL21DE3 137.5
# 3
#                        fragment_name  fragment start (aa)  \
# 2602  gyrB1copies_1-804_gyrA_119-148                  119
# 2604  gyrB1copies_1-804_gyrA_121-150                  121
# 2606  gyrB1copies_1-804_gyrA_123-152                  123
#
#       fragment center (aa)  fragment end (aa)      iptm      plddt  \
# 2602                 133.5                148  0.274323  30.320000
# 2604                 135.5                150  0.230492  36.767667
# 2606                 137.5                152  0.188093  45.225000
#
#       n_contacts                                               path _merge  \
# 2602          13  /data1/groups/keatinglab/swans/savinovCollabor...   both
# 2604          19  /data1/groups/keatinglab/swans/savinovCollabor...   both
# 2606          16  /data1/groups/keatinglab/swans/savinovCollabor...   both
#
#       weighted_contacts  ... charge_Lehninger_classifier  \
# 2602           3.566198  ...                         NaN
# 2604           4.379348  ...                         NaN
# 2606           3.009485  ...                    negative
#
#      frag_contains_alphaHelix frag_contains_betaStrand  frag_contains_Turn  \
# 2602                      NaN                      NaN                 NaN
# 2604                      NaN                      NaN                 NaN
# 2606                      1.0                      1.0                 1.0
#
#       frag_centroid_fractional_position_classifier  \
# 2602                                           NaN
# 2604                                           NaN
# 2606                                    N-terminal
#
#                                             contact_set cluster cluster_size  \
# 2602  [(<Residue THR het=  resseq=508 icode= >, <Res...      20            1
# 2604  [(<Residue LEU het=  resseq=763 icode= >, <Res...      22            1
# 2606  [(<Residue LEU het=  resseq=763 icode= >, <Res...      21            1
#
#      cluster first fragment center (aa)  cluster last fragment center (aa)
# 2602                              133.5                              133.5
# 2604                              135.5                              135.5
# 2606                              137.5                              137.5
#
# [3 rows x 28 columns]
# gyrA-coding-EcoliBL21DE3 147.5
# 0
# Empty DataFrame
# Columns: [fragment_name, fragment start (aa), fragment center (aa), fragment end (aa), iptm, plddt, n_contacts, path, _merge, weighted_contacts, gene, condition, fragment ID, fragment length (aa), E = inhibitory effect (enrichment), sem(E), hydrophobicity_KyteDoolittle_classifier, instabIndex_Guruprasad_classifier, charge_Lehninger_classifier, frag_contains_alphaHelix, frag_contains_betaStrand, frag_contains_Turn, frag_centroid_fractional_position_classifier, contact_set, cluster, cluster_size, cluster first fragment center (aa), cluster last fragment center (aa)]
# Index: []
#
# [0 rows x 28 columns]
# gyrA-coding-EcoliBL21DE3 183.5
# 0
# Empty DataFrame
# Columns: [fragment_name, fragment start (aa), fragment center (aa), fragment end (aa), iptm, plddt, n_contacts, path, _merge, weighted_contacts, gene, condition, fragment ID, fragment length (aa), E = inhibitory effect (enrichment), sem(E), hydrophobicity_KyteDoolittle_classifier, instabIndex_Guruprasad_classifier, charge_Lehninger_classifier, frag_contains_alphaHelix, frag_contains_betaStrand, frag_contains_Turn, frag_centroid_fractional_position_classifier, contact_set, cluster, cluster_size, cluster first fragment center (aa), cluster last fragment center (aa)]
# Index: []
#
# [0 rows x 28 columns]
# gyrA-coding-EcoliBL21DE3 270.5
# 0
# Empty DataFrame
# Columns: [fragment_name, fragment start (aa), fragment center (aa), fragment end (aa), iptm, plddt, n_contacts, path, _merge, weighted_contacts, gene, condition, fragment ID, fragment length (aa), E = inhibitory effect (enrichment), sem(E), hydrophobicity_KyteDoolittle_classifier, instabIndex_Guruprasad_classifier, charge_Lehninger_classifier, frag_contains_alphaHelix, frag_contains_betaStrand, frag_contains_Turn, frag_centroid_fractional_position_classifier, contact_set, cluster, cluster_size, cluster first fragment center (aa), cluster last fragment center (aa)]
# Index: []
#
# [0 rows x 28 columns]
# gyrA-coding-EcoliBL21DE3 340.5
# 0
# Empty DataFrame
# Columns: [fragment_name, fragment start (aa), fragment center (aa), fragment end (aa), iptm, plddt, n_contacts, path, _merge, weighted_contacts, gene, condition, fragment ID, fragment length (aa), E = inhibitory effect (enrichment), sem(E), hydrophobicity_KyteDoolittle_classifier, instabIndex_Guruprasad_classifier, charge_Lehninger_classifier, frag_contains_alphaHelix, frag_contains_betaStrand, frag_contains_Turn, frag_centroid_fractional_position_classifier, contact_set, cluster, cluster_size, cluster first fragment center (aa), cluster last fragment center (aa)]
# Index: []
#
# [0 rows x 28 columns]
# gyrA-coding-EcoliBL21DE3 375.5
# 0
# Empty DataFrame
# Columns: [fragment_name, fragment start (aa), fragment center (aa), fragment end (aa), iptm, plddt, n_contacts, path, _merge, weighted_contacts, gene, condition, fragment ID, fragment length (aa), E = inhibitory effect (enrichment), sem(E), hydrophobicity_KyteDoolittle_classifier, instabIndex_Guruprasad_classifier, charge_Lehninger_classifier, frag_contains_alphaHelix, frag_contains_betaStrand, frag_contains_Turn, frag_centroid_fractional_position_classifier, contact_set, cluster, cluster_size, cluster first fragment center (aa), cluster last fragment center (aa)]
# Index: []
#
# [0 rows x 28 columns]
# gyrA-coding-EcoliBL21DE3 382.5
# 4
#                        fragment_name  fragment start (aa)  \
# 2019         gyrA_1-872_gyrA_379-408                  379
# 2849  gyrB1copies_1-804_gyrA_366-395                  366
# 2850  gyrB1copies_1-804_gyrA_367-396                  367
# 2851  gyrB1copies_1-804_gyrA_368-397                  368
#
#       fragment center (aa)  fragment end (aa)      iptm      plddt  \
# 2019                 393.5                408  0.902727  89.258000
# 2849                 380.5                395  0.387146  56.934000
# 2850                 381.5                396  0.410425  58.742333
# 2851                 382.5                397  0.397560  56.454667
#
#       n_contacts                                               path _merge  \
# 2019           7  /data1/groups/keatinglab/swans/savinovCollabor...   both
# 2849           8  /data1/groups/keatinglab/swans/savinovCollabor...   both
# 2850          11  /data1/groups/keatinglab/swans/savinovCollabor...   both
# 2851          11  /data1/groups/keatinglab/swans/savinovCollabor...   both
#
#       weighted_contacts  ... charge_Lehninger_classifier  \
# 2019           6.319088  ...                    negative
# 2849           3.097166  ...                     neutral
# 2850           4.514674  ...                     neutral
# 2851           4.373161  ...                     neutral
#
#      frag_contains_alphaHelix frag_contains_betaStrand  frag_contains_Turn  \
# 2019                      1.0                      1.0                 0.0
# 2849                      1.0                      0.0                 0.0
# 2850                      1.0                      0.0                 0.0
# 2851                      1.0                      0.0                 0.0
#
#       frag_centroid_fractional_position_classifier  \
# 2019                                       central
# 2849                                       central
# 2850                                       central
# 2851                                       central
#
#                                             contact_set cluster cluster_size  \
# 2019  [(<Residue THR het=  resseq=467 icode= >, <Res...       7           25
# 2849  [(<Residue SER het=  resseq=504 icode= >, <Res...      16            1
# 2850  [(<Residue ILE het=  resseq=804 icode= >, <Res...      29            1
# 2851  [(<Residue SER het=  resseq=504 icode= >, <Res...      17            1
#
#      cluster first fragment center (aa)  cluster last fragment center (aa)
# 2019                              388.5                              412.5
# 2849                              380.5                              380.5
# 2850                              381.5                              381.5
# 2851                              382.5                              382.5
#
# [4 rows x 28 columns]
# gyrA-coding-EcoliBL21DE3 489.5
# 3
#                        fragment_name  fragment start (aa)  \
# 2081         gyrA_1-872_gyrA_441-470                  441
# 2937  gyrB1copies_1-804_gyrA_454-483                  454
# 2939  gyrB1copies_1-804_gyrA_456-485                  456
#
#       fragment center (aa)  fragment end (aa)      iptm      plddt  \
# 2081                 455.5                470  0.920554  91.484000
# 2937                 468.5                483  0.471802  61.500333
# 2939                 470.5                485  0.349238  53.174667
#
#       n_contacts                                               path _merge  \
# 2081          19  /data1/groups/keatinglab/swans/savinovCollabor...   both
# 2937          13  /data1/groups/keatinglab/swans/savinovCollabor...   both
# 2939          13  /data1/groups/keatinglab/swans/savinovCollabor...   both
#
#       weighted_contacts  ... charge_Lehninger_classifier  \
# 2081          17.490527  ...                     neutral
# 2937           6.133425  ...                    negative
# 2939           4.540091  ...                    negative
#
#      frag_contains_alphaHelix frag_contains_betaStrand  frag_contains_Turn  \
# 2081                      1.0                      1.0                 0.0
# 2937                      1.0                      0.0                 0.0
# 2939                      1.0                      0.0                 0.0
#
#       frag_centroid_fractional_position_classifier  \
# 2081                                       central
# 2937                                       central
# 2939                                       central
#
#                                             contact_set cluster cluster_size  \
# 2081  [(<Residue GLN het=  resseq=464 icode= >, <Res...       6           33
# 2937  [(<Residue ILE het=  resseq=802 icode= >, <Res...      13            4
# 2939  [(<Residue MET het=  resseq=781 icode= >, <Res...      12            2
#
#      cluster first fragment center (aa)  cluster last fragment center (aa)
# 2081                              445.5                              478.5
# 2937                              466.5                              469.5
# 2939                              470.5                              471.5
#
# [3 rows x 28 columns]
# gyrA-coding-EcoliBL21DE3 492.5
# 0
# Empty DataFrame
# Columns: [fragment_name, fragment start (aa), fragment center (aa), fragment end (aa), iptm, plddt, n_contacts, path, _merge, weighted_contacts, gene, condition, fragment ID, fragment length (aa), E = inhibitory effect (enrichment), sem(E), hydrophobicity_KyteDoolittle_classifier, instabIndex_Guruprasad_classifier, charge_Lehninger_classifier, frag_contains_alphaHelix, frag_contains_betaStrand, frag_contains_Turn, frag_centroid_fractional_position_classifier, contact_set, cluster, cluster_size, cluster first fragment center (aa), cluster last fragment center (aa)]
# Index: []
#
# [0 rows x 28 columns]
# gyrA-coding-EcoliBL21DE3 669.5
# 0
# Empty DataFrame
# Columns: [fragment_name, fragment start (aa), fragment center (aa), fragment end (aa), iptm, plddt, n_contacts, path, _merge, weighted_contacts, gene, condition, fragment ID, fragment length (aa), E = inhibitory effect (enrichment), sem(E), hydrophobicity_KyteDoolittle_classifier, instabIndex_Guruprasad_classifier, charge_Lehninger_classifier, frag_contains_alphaHelix, frag_contains_betaStrand, frag_contains_Turn, frag_centroid_fractional_position_classifier, contact_set, cluster, cluster_size, cluster first fragment center (aa), cluster last fragment center (aa)]
# Index: []
#
# [0 rows x 28 columns]
# gyrA-coding-EcoliBL21DE3 783.5
# 0
# Empty DataFrame
# Columns: [fragment_name, fragment start (aa), fragment center (aa), fragment end (aa), iptm, plddt, n_contacts, path, _merge, weighted_contacts, gene, condition, fragment ID, fragment length (aa), E = inhibitory effect (enrichment), sem(E), hydrophobicity_KyteDoolittle_classifier, instabIndex_Guruprasad_classifier, charge_Lehninger_classifier, frag_contains_alphaHelix, frag_contains_betaStrand, frag_contains_Turn, frag_centroid_fractional_position_classifier, contact_set, cluster, cluster_size, cluster first fragment center (aa), cluster last fragment center (aa)]
# Index: []
#
# [0 rows x 28 columns]
# lptG-coding-EcoliBL21DE3 20.5
# 0
# Empty DataFrame
# Columns: [fragment_name, fragment start (aa), fragment center (aa), fragment end (aa), iptm, plddt, n_contacts, path, _merge, weighted_contacts, gene, condition, fragment ID, fragment length (aa), E = inhibitory effect (enrichment), sem(E), hydrophobicity_KyteDoolittle_classifier, instabIndex_Guruprasad_classifier, charge_Lehninger_classifier, frag_contains_alphaHelix, frag_contains_betaStrand, frag_contains_Turn, frag_centroid_fractional_position_classifier, contact_set, cluster, cluster_size, cluster first fragment center (aa), cluster last fragment center (aa)]
# Index: []
#
# [0 rows x 28 columns]
# lptG-coding-EcoliBL21DE3 76.5
# 1
#                      fragment_name  fragment start (aa)  fragment center (aa)  \
# 3742  lptF1copies_1-366_lptG_69-82                   69                  75.5
#
#       fragment end (aa)      iptm      plddt  n_contacts  \
# 3742                 82  0.645626  61.062333           5
#
#                                                    path _merge  \
# 3742  /data1/groups/keatinglab/swans/savinovCollabor...   both
#
#       weighted_contacts  ... charge_Lehninger_classifier  \
# 3742           3.228132  ...                     neutral
#
#      frag_contains_alphaHelix frag_contains_betaStrand  frag_contains_Turn  \
# 3742                      1.0                      0.0                 0.0
#
#       frag_centroid_fractional_position_classifier  \
# 3742                                    N-terminal
#
#                                             contact_set cluster cluster_size  \
# 3742  [(<Residue ILE het=  resseq=25 icode= >, <Resi...      31            1
#
#      cluster first fragment center (aa)  cluster last fragment center (aa)
# 3742                               75.5                               75.5
#
# [1 rows x 28 columns]
# lptG-coding-EcoliBL21DE3 291.5
# 0
# Empty DataFrame
# Columns: [fragment_name, fragment start (aa), fragment center (aa), fragment end (aa), iptm, plddt, n_contacts, path, _merge, weighted_contacts, gene, condition, fragment ID, fragment length (aa), E = inhibitory effect (enrichment), sem(E), hydrophobicity_KyteDoolittle_classifier, instabIndex_Guruprasad_classifier, charge_Lehninger_classifier, frag_contains_alphaHelix, frag_contains_betaStrand, frag_contains_Turn, frag_centroid_fractional_position_classifier, contact_set, cluster, cluster_size, cluster first fragment center (aa), cluster last fragment center (aa)]
# Index: []
#
# [0 rows x 28 columns]
# lptG-coding-EcoliBL21DE3 323.5
# 1
#                        fragment_name  fragment start (aa)  \
# 3986  lptF1copies_1-366_lptG_313-326                  313
#
#       fragment center (aa)  fragment end (aa)      iptm   plddt  n_contacts  \
# 3986                 319.5                326  0.865082  65.854          10
#
#                                                    path _merge  \
# 3986  /data1/groups/keatinglab/swans/savinovCollabor...   both
#
#       weighted_contacts  ... charge_Lehninger_classifier  \
# 3986           8.650821  ...                    negative
#
#      frag_contains_alphaHelix frag_contains_betaStrand  frag_contains_Turn  \
# 3986                      1.0                      0.0                 0.0
#
#       frag_centroid_fractional_position_classifier  \
# 3986                                    C-terminal
#
#                                             contact_set cluster cluster_size  \
# 3986  [(<Residue LEU het=  resseq=311 icode= >, <Res...       3            4
#
#      cluster first fragment center (aa)  cluster last fragment center (aa)
# 3986                              318.5                              321.5
#
# [1 rows x 28 columns]
# rplL-coding-EcoliBL21DE3 19.5
# 2
#              fragment_name  fragment start (aa)  fragment center (aa)  \
# 4021  rpIL_1-121_rpIL_1-30                    1                  15.5
# 4024  rpIL_1-121_rpIL_4-33                    4                  18.5
#
#       fragment end (aa)      iptm      plddt  n_contacts  \
# 4021                 30  0.565762  81.310333           6
# 4024                 33  0.650886  76.554667          13
#
#                                                    path _merge  \
# 4021  /data1/groups/keatinglab/swans/savinovCollabor...   both
# 4024  /data1/groups/keatinglab/swans/savinovCollabor...   both
#
#       weighted_contacts  ... charge_Lehninger_classifier  \
# 4021           3.394572  ...                    negative
# 4024           8.461522  ...                         NaN
#
#      frag_contains_alphaHelix frag_contains_betaStrand  frag_contains_Turn  \
# 4021                      1.0                      1.0                 0.0
# 4024                      NaN                      NaN                 NaN
#
#       frag_centroid_fractional_position_classifier  \
# 4021                                    N-terminal
# 4024                                           NaN
#
#                                             contact_set cluster cluster_size  \
# 4021  [(<Residue ILE het=  resseq=9 icode= >, <Resid...       2            1
# 4024  [(<Residue ILE het=  resseq=9 icode= >, <Resid...       1            5
#
#      cluster first fragment center (aa)  cluster last fragment center (aa)
# 4021                               15.5                               15.5
# 4024                               18.5                               28.5
#
# [2 rows x 28 columns]
# ssb-coding-EcoliBL21DE3 66.5
# 5
#                    fragment_name  fragment start (aa)  fragment center (aa)  \
# 4515  ssb4copies_1-178_ssb_44-73                   44                  58.5
# 4516  ssb4copies_1-178_ssb_45-74                   45                  59.5
# 4517  ssb4copies_1-178_ssb_46-75                   46                  60.5
# 4519  ssb4copies_1-178_ssb_48-77                   48                  62.5
# 4521  ssb4copies_1-178_ssb_50-79                   50                  64.5
#
#       fragment end (aa)      iptm      plddt  n_contacts  \
# 4515                 73  0.675513  64.019000           5
# 4516                 74  0.671282  62.042333           5
# 4517                 75  0.674440  63.216333          14
# 4519                 77  0.674205  68.619000           6
# 4521                 79  0.675793  75.528333           5
#
#                                                    path _merge  \
# 4515  /data1/groups/keatinglab/swans/savinovCollabor...   both
# 4516  /data1/groups/keatinglab/swans/savinovCollabor...   both
# 4517  /data1/groups/keatinglab/swans/savinovCollabor...   both
# 4519  /data1/groups/keatinglab/swans/savinovCollabor...   both
# 4521  /data1/groups/keatinglab/swans/savinovCollabor...   both
#
#       weighted_contacts  ... charge_Lehninger_classifier  \
# 4515           3.377566  ...                     neutral
# 4516           3.356412  ...                     neutral
# 4517           9.442162  ...                     neutral
# 4519           4.045230  ...                     neutral
# 4521           3.378966  ...                    positive
#
#      frag_contains_alphaHelix frag_contains_betaStrand  frag_contains_Turn  \
# 4515                      1.0                      1.0                 0.0
# 4516                      1.0                      1.0                 0.0
# 4517                      1.0                      1.0                 0.0
# 4519                      1.0                      1.0                 0.0
# 4521                      1.0                      1.0                 0.0
#
#       frag_centroid_fractional_position_classifier  \
# 4515                                    N-terminal
# 4516                                       central
# 4517                                       central
# 4519                                       central
# 4521                                       central
#
#                                             contact_set cluster cluster_size  \
# 4515  [(<Residue LEU het=  resseq=113 icode= >, <Res...      40            1
# 4516  [(<Residue MET het=  resseq=49 icode= >, <Resi...      30            1
# 4517  [(<Residue ILE het=  resseq=12 icode= >, <Resi...      49            1
# 4519  [(<Residue LYS het=  resseq=4 icode= >, <Resid...      42            1
# 4521  [(<Residue LEU het=  resseq=113 icode= >, <Res...       1            1
#
#      cluster first fragment center (aa)  cluster last fragment center (aa)
# 4515                               58.5                               58.5
# 4516                               59.5                               59.5
# 4517                               60.5                               60.5
# 4519                               62.5                               62.5
# 4521                               64.5                               64.5
#
# [5 rows x 28 columns]
# ssb-coding-EcoliBL21DE3 94.5
# 0
# Empty DataFrame
# Columns: [fragment_name, fragment start (aa), fragment center (aa), fragment end (aa), iptm, plddt, n_contacts, path, _merge, weighted_contacts, gene, condition, fragment ID, fragment length (aa), E = inhibitory effect (enrichment), sem(E), hydrophobicity_KyteDoolittle_classifier, instabIndex_Guruprasad_classifier, charge_Lehninger_classifier, frag_contains_alphaHelix, frag_contains_betaStrand, frag_contains_Turn, frag_centroid_fractional_position_classifier, contact_set, cluster, cluster_size, cluster first fragment center (aa), cluster last fragment center (aa)]
# Index: []
#
# [0 rows x 28 columns]
# 39 experimental fragments with significant inhibition and 16 overlapping alphafold predictions

# %%
exp_filt_df[exp_filt_df['covered']==True][['gene','fragment center (aa)','covering','peak type']]
# Out:
#                         gene  fragment center (aa)  \
# 12  ftsZ-coding-EcoliBL21DE3                 174.5
# 13  ftsZ-coding-EcoliBL21DE3                 190.5
# 14  ftsZ-coding-EcoliBL21DE3                 213.5
# 15  ftsZ-coding-EcoliBL21DE3                 272.5
# 16  ftsZ-coding-EcoliBL21DE3                 367.5
# 17  groL-coding-EcoliBL21DE3                  17.5
# 21  groL-coding-EcoliBL21DE3                 260.5
# 22  gyrA-coding-EcoliBL21DE3                  26.5
# 23  gyrA-coding-EcoliBL21DE3                  89.5
# 24  gyrA-coding-EcoliBL21DE3                 137.5
# 30  gyrA-coding-EcoliBL21DE3                 382.5
# 31  gyrA-coding-EcoliBL21DE3                 489.5
# 61  lptG-coding-EcoliBL21DE3                  76.5
# 63  lptG-coding-EcoliBL21DE3                 323.5
# 64  rplL-coding-EcoliBL21DE3                  19.5
# 93   ssb-coding-EcoliBL21DE3                  66.5
#
#                                              covering peak type
# 12                         [FtsZ_10-316_FtsZ_166-195]     known
# 13                         [FtsZ_10-316_FtsZ_187-216]     known
# 14                         [FtsZ_10-316_FtsZ_187-216]     novel
# 15                         [FtsZ_10-316_FtsZ_266-295]     known
# 16                         [FtsZ_10-316_FtsZ_352-381]     known
# 17                           [groEL_1-548_groEL_1-30]     known
# 21                  [groES1copies_1-97_groEL_250-279]     known
# 22                      [gyrB1copies_1-804_gyrA_2-31]     known
# 23  [gyrA_1-872_gyrA_62-91, gyrB1copies_1-804_gyrA...     novel
# 24  [gyrB1copies_1-804_gyrA_119-148, gyrB1copies_1...     novel
# 30  [gyrA_1-872_gyrA_379-408, gyrB1copies_1-804_gy...     known
# 31  [gyrA_1-872_gyrA_441-470, gyrB1copies_1-804_gy...     novel
# 61                     [lptF1copies_1-366_lptG_69-82]     novel
# 63                   [lptF1copies_1-366_lptG_313-326]     known
# 64       [rpIL_1-121_rpIL_1-30, rpIL_1-121_rpIL_4-33]     known
# 93  [ssb4copies_1-178_ssb_44-73, ssb4copies_1-178_...     known

# %%
exp_filt_df[(exp_filt_df['covered']==True)&(exp_filt_df['peak type']=='known')][['gene','fragment center (aa)','covering']]
# Out:
#                         gene  fragment center (aa)  \
# 12  ftsZ-coding-EcoliBL21DE3                 174.5
# 13  ftsZ-coding-EcoliBL21DE3                 190.5
# 15  ftsZ-coding-EcoliBL21DE3                 272.5
# 16  ftsZ-coding-EcoliBL21DE3                 367.5
# 17  groL-coding-EcoliBL21DE3                  17.5
# 21  groL-coding-EcoliBL21DE3                 260.5
# 22  gyrA-coding-EcoliBL21DE3                  26.5
# 30  gyrA-coding-EcoliBL21DE3                 382.5
# 63  lptG-coding-EcoliBL21DE3                 323.5
# 64  rplL-coding-EcoliBL21DE3                  19.5
# 93   ssb-coding-EcoliBL21DE3                  66.5
#
#                                              covering
# 12                         [FtsZ_10-316_FtsZ_166-195]
# 13                         [FtsZ_10-316_FtsZ_187-216]
# 15                         [FtsZ_10-316_FtsZ_266-295]
# 16                         [FtsZ_10-316_FtsZ_352-381]
# 17                           [groEL_1-548_groEL_1-30]
# 21                  [groES1copies_1-97_groEL_250-279]
# 22                      [gyrB1copies_1-804_gyrA_2-31]
# 30  [gyrA_1-872_gyrA_379-408, gyrB1copies_1-804_gy...
# 63                   [lptF1copies_1-366_lptG_313-326]
# 64       [rpIL_1-121_rpIL_1-30, rpIL_1-121_rpIL_4-33]
# 93  [ssb4copies_1-178_ssb_44-73, ssb4copies_1-178_...
